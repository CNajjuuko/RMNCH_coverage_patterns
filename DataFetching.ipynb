# %%
import os
import zipfile
import pandas as pd
import numpy as np
import pathlib
import shapefile
import pyreadstat
from tqdm import tqdm
import pickle

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
# Setting data folder
working_directory = os.getcwd()
data_folder = '../extracted_files'

# %%
# Unzipping and reading the birth recode files
for item in os.listdir(working_directory):
    if item.endswith('.zip') and "BR" in item and "DT" in item:
        print(f"Unzipping: {item}")
        with zipfile.ZipFile(item, 'r') as zip_ref:
            zip_ref.extractall(data_folder)            
BR_data = {}
BR_metadata = {}
for file in pathlib.Path(data_folder).glob('*BR*.DTA'):
    country_code = file.name[:2]
    df, meta = pyreadstat.read_dta(file)
    df = df.assign(country=country_code)
    BR_data[country_code] = df
    BR_metadata[country_code] = meta   
if not BR_data:
    print("No BR_dataframes created. Check if .DTA files are present in the expected pattern.")
else:
    print(f"Created BR_dataframes for {len(BR_data)} countries.")
# Out:
# Created BR_dataframes for 31 countries.

# %%
# unzipping and reading the geolocalisation (GE data) for all countries from the data folder
for item in os.listdir(working_directory):
    if item.endswith('.zip') and "GE" in item and "FL" in item:
        print(f"Unzipping: {item}")
        with zipfile.ZipFile(item, 'r') as zip_ref:
            zip_ref.extractall(data_folder)           
GE_data = {}
for file in pathlib.Path(data_folder).glob('*GE*.shp'):
    country_code = file.name[:2]
    sf = shapefile.Reader(str(file))
    fields = [x[0] for x in sf.fields][1:]
    records = sf.records()
    GE_data[country_code] = pd.DataFrame(columns=fields, data=records)    
if not GE_data:
    print("No GE_data created. Check if .shp files are present in the expected pattern.")
else:
    print(f"Created GE_dataframes for {len(GE_data)} countries.")
# Out:
# Created GE_dataframes for 31 countries.

# %%
# merge the child, and geospatial recodes
BRGE_data = {}
for country in BR_data.keys():
    if country in GE_data:
        BRGE_data[country] = BR_data[country].merge(GE_data[country].set_index(['DHSCLUST', 'DHSCC']), right_index=True, left_on=['v001', 'country'], how='inner')
        print(f"Merging: {country}")
    else:
        print(f"No geolocation data to merge for country code: {country}")

print(f"Merged birth and geospatial recode data for {len(BRGE_data)} countries.")
# Out:
# Merging: MR
# Merging: KE
# Merging: ET
# Merging: NG
# Merging: ZW
# Merging: UG
# Merging: BU
# Merging: BJ
# Merging: GA
# Merging: AO
# Merging: MW
# Merging: MZ
# Merging: TZ
# Merging: MD
# Merging: ML
# Merging: CI
# Merging: CM
# Merging: SL
# Merging: CD
# Merging: ZA
# Merging: TD
# Merging: GM
# Merging: BF
# Merging: GN
# Merging: GH
# Merging: LS
# Merging: TG
# Merging: SN
# Merging: RW
# Merging: LB
# Merging: ZM
# Merged birth and geospatial recode data for 31 countries.

# %%
# get the total number of births cases - all children born to the women being interviewed
births = []
for country in BRGE_data.keys():
    number_of_births = len(BRGE_data[country])
    print(f"{country}: {number_of_births}")
    births.append(number_of_births)

print(f"Total birth cases: {sum(births)}")

# get the number of columns for all countries' datasets
for country in BRGE_data.keys():
    number_of_columns = len(BRGE_data[country].columns)
    print(f"{country}: {number_of_columns}")
# Out:
# MR: 39793
# KE: 77381
# ET: 41392
# NG: 127545
# ZW: 20791
# UG: 57906
# BU: 45419
# BJ: 45853
# GA: 23232
# AO: 42002
# MW: 68074
# MZ: 33900
# TZ: 40394
# MD: 47720
# ML: 33379
# CI: 39979
# CM: 33988
# SL: 40543
# CD: 59276
# ZA: 14144
# TD: 68989
# GM: 31665
# BF: 48745
# GN: 28887
# GH: 34663
# LS: 11710
# TG: 26264
# SN: 21562
# RW: 30820
# LB: 24765
# ZM: 38446
# Total birth cases: 1299227
# MR: 1178
# KE: 1338
# ET: 1306
# NG: 1221
# ZW: 1133
# UG: 1156
# BU: 1155
# BJ: 1207
# GA: 1250
# AO: 1179
# MW: 1116
# MZ: 1396
# TZ: 1369
# MD: 1181
# ML: 1257
# CI: 1183
# CM: 1231
# SL: 1192
# CD: 1018
# ZA: 1059
# TD: 1071
# GM: 1272
# BF: 1157
# GN: 1188
# GH: 1267
# LS: 1002
# TG: 1073
# SN: 1210
# RW: 1235
# LB: 1240
# ZM: 1154

# %%
# Check which columns are different and count them
reference_columns = BRGE_data[list(BRGE_data.keys())[0]].columns

for country, df in BRGE_data.items():
    if set(df.columns) == set(reference_columns):
        print(f"{country}: Columns match")
    else:
        similar_columns = set(df.columns).intersection(set(reference_columns))
        missing_columns = set(reference_columns) - set(df.columns)
        additional_columns = set(df.columns) - set(reference_columns)
        print(f"{country}: Columns do not match")

        if similar_columns:
            print(f"    Similar columns ({len(similar_columns)}): {similar_columns}")
        if missing_columns:
            print(f"    Missing columns ({len(missing_columns)}): {missing_columns}")
        if additional_columns:
            print(f"    Additional columns ({len(additional_columns)}): {additional_columns}")
# Out:
# MR: Columns match
# KE: Columns do not match
#     Similar columns (942): {'v140', 'h21', 'hw56', 'm57a', 'h53d', 'v105', 'v525', 'ALT_GPS', 'v222', 'v469x', 'v028', 'v155', 'v413a', 'v411', 'v376', 'v745c', 'h8', 'v401', 'h12v', 'm57u', 'v104', 'v3a08f', 'v458', 'm2a', 'v007', 'v507', 'v414i', 'v223', 'v472a', 'h58d', 'h50', 'h62d', 'v481g', 'm2d', 'hw53', 'v394', 'idx94', 'v3a01', 'v045b', 'm57h', 'v414u', 'v743a', 'v3a00i', 'v404', 'v013', 'm45', 'h12w', 'h43', 'h12f', 'v204', 'v413', 'v014', 'h15j', 'v231', 'h53', 'hw70', 'm57v', 'm1', 'm57m', 'v3a08d', 'm57p', 'm19', 'b9', 'h12t', 'bidx', 'v001', 'v602', 'v633c', 'h37aa', 'h37z', 'v017', 'g122', 'v420', 'h6', 'h37c', 'awfacte', 'v153', 'm42d', 'v008', 'm8', 'v3a08ad', 'h13b', 'h62m', 'v731', 'v472h', 'h5', 'h15g', 'h14', 'h10', 'h63', 'h13', 'h11b', 'h57', 'v633g', 'v467c', 'v471e', 'm47', 'h66', 'v502', 'v310', 'h56', 'b18', 'v471b', 'v501', 'v504', 'v168', 'v191a', 'm39a', 'v319', 'hw18', 'v131', 'v631', 'v510', 'v3a08r', 'v3a00y', 'v616', 'h80e', 'v032', 'h5m', 'v015', 'h37h', 'v3a08q', 'h31d', 'v364', 'b5', 'v137', 'm49a', 'h6d', 'v415', 'v107', 'm78b', 'v232', 'h32r', 'v3a00r', 'h63m', 'v325a', 'h9m', 'h52y', 'h33', 'h15c', 'v216', 'DHSID', 'v414s', 'h37n', 'v045c', 'v129', 'h32m', 'v472q', 'v3a00d', 'h59m', 'v463h', 'h32h', 'v3a00q', 'h37p', 'ADM1FIPSNA', 'h60', 'm78d', 'v235', 'v466', 'm15', 'm27', 'country', 'v3a00n', 'h21a', 'h12p', 'v3a08o', 'v633b', 'v411a', 'awfactr', 'v233', 'h55', 'v744a', 'h6y', 'v511', 'h12y', 'v150', 'v471f', 'v315', 'v190', 'v3a08aa', 'v363', 'v472j', 'v535', 'm49g', 'h2y', 'v414j', 'h53y', 'v604', 'v134', 'b15', 'h32b', 'v508', 'v412b', 'v481c', 'm1a', 'v745b', 'v452a', 'h9', 'v472d', 'ADM1SALBCO', 'h37d', 'm36', 'v205', 'h15i', 'h50d', 'h32q', 'h37e', 'hidx', 'm70', 'v113', 'm49c', 'm44', 'v512', 'h7', 'm19a', 'v627', 'v418a', 'b3', 'DHSYEAR', 'h9a', 'v416', 'v3a00t', 'v505', 'h32i', 'v214', 'v454', 'v3a00e', 'v021', 'h3m', 'm2i', 'h32u', 'h63d', 'v3a08l', 'v102', 'v482b', 'v743b', 'v715', 'v456', 'm1b', 'm72', 'v203', 'v237', 'v481f', 'm39', 'v3a04', 'h40y', 'v477', 'b20', 'hw71', 'h5y', 'v019a', 'h37b', 'v138', 'v3a00v', 'v467a', 'h57m', 'v414l', 'm10', 'm57i', 'h37m', 'ml101', 'v472t', 'SOURCE', 'v215', 'm61', 'v012', 'v3a08u', 'v224', 'v395', 'h37k', 'b1', 'v159', 'v414w', 'h50m', 'v413c', 'v3a00w', 'm2e', 'm3c', 'h2', 'h64y', 'h12s', 'v026', 'v3a09a', 'v414f', 'h58m', 'h38', 'm48', 'v481x', 'v509', 'v3a03', 'v3a00z', 'b13', 'b16', 'v023', 'v3a09b', 'awfactu', 'v472b', 'h57d', 'v634', 'v407', 'v406', 'v506', 'v530', 'h60y', 'm3d', 'v626', 'ADM1SALBNA', 'v130', 'v239', 'v3a08s', 'v480', 'h15h', 'h39', 'v008a', 'h60m', 'v379', 'v3a00b', 'v531', 'm64', 'h65y', 'h32n', 'h7y', 'v367', 'v459', 'v605', 'v463z', 'v457', 'v745a', 'h58', 'v152', 'v141', 'b12', 'h66d', 'ADM1DHS', 'v228', 'v169a', 'h9ad', 'm78i', 'h54d', 'v125', 'v220', 'hw55', 'v359', 'v481a', 'h32v', 'v746', 'v120', 'v467k', 'm78g', 'v467j', 'h52m', 'v3a08m', 'v312', 'm2b', 'h60d', 'v209', 'v472p', 'v453', 'h4m', 'v318', 'v414h', 'b8', 'ml0', 'b2', 'h2d', 'v115', 'm3m', 'b10', 'h32g', 'idx95', 'v743c', 'v240', 'v029', 'h15d', 'h62', 'v414g', 'v025', 'v3a00c', 'h51m', 'v529', 'v3a08c', 'h12r', 'LONGNUM', 'm13', 'v437', 'DHSREGCO', 'h55d', 'h55m', 'm2j', 'v464', 'hw17', 'h12m', 'v3a00j', 'v472n', 'v452b', 'h66y', 'm66', 'v472l', 'v414n', 'h32x', 'v463c', 'v539', 'v471d', 'v463b', 'v472m', 'h51', 'h52', 'v704', 'v384b', 'v3a08t', 'v322', 'h33d', 'caseid', 'v3a08h', 'm3k', 'h61', 'v011', 'h32c', 'm2l', 'v621', 'm6', 'v242', 'midx', 'm2h', 'v739', 'm73', 'm43', 'v472r', 'v537', 'v478', 'h63y', 'm60', 'h65', 'm2m', 'v463f', 'v171a', 'v027', 'v208', 'v471c', 'h33m', 'h51d', 'm57r', 'awfactw', 'v455', 'URBAN_RURA', 'LATNUM', 'v135', 'v412', 'm2g', 'v463a', 'm1e', 'h59y', 'v169b', 'h37x', 'h80f', 'v414o', 'v482a', 'v463l', 'v412a', 'v3a08z', 'v045a', 'v122', 'hw72', 'h15k', 'v393', 'h22', 'v468', 'bord', 'v744d', 'm4', 'm57q', 'v003', 'h55y', 'm57t', 'v633d', 'v166', 'v472f', 'h6m', 'h8m', 'v413d', 'v103', 'h32a', 'v3a00h', 'v467 ...
#     Missing columns (236): {'v474f', 'm65g', 'ml13a', 'm65b', 'v442', 'm55g', 'ml17a', 'g117j', 'ml13y', 'ml13o', 'hw12', 'ml14y', 'g111', 'h36d', 's1213', 's1232', 'm55h', 's1208', 'h36e', 'm55f', 'ml19c', 'h44c', 'ml16c', 'v475', 's1202', 'ml13g', 'g117i', 'm65a', 'g114', 'v474e', 's1203', 'g117g', 's470c', 'm65c', 'sresid', 'ml11', 's711ad', 'g103', 'h36b', 'ml13p', 'g117x', 'h45', 'ml14z', 's1212', 's1230', 'hw9', 's524ae', 's1215', 'm65j', 'ml21a', 's108', 'm65k', 'ml23c', 'ml13l', 'm55n', 'm55i', 'ml21c', 'g117a', 's1214', 's711ab', 's711aa', 'ml13n', 's1211', 'ml23a', 'g118', 'ml15b', 's1216', 'm55a', 'ml13f', 'ml24c', 'm55c', 'm65i', 's1233', 'ml13ab', 'ml19b', 'm55l', 'idxml', 'h41a', 'h36f', 's1209', 's1228', 'ml13da', 's904', 'g110', 's524af', 's470b', 's1312a', 'm55o', 'm55m', 'm65e', 'ml18a', 'v474c', 'v474z', 'v440', 'ml17c', 'ml16b', 's1220', 'ml21b', 'm65d', 'v476', 's815e', 's1113', 'g102', 'ml13z', 's1226', 'hw4', 's1201', 'ml19e', 'ml16a', 'ml13m', 'g100', 'g117b', 'ml25a', 'ml22c', 'v439', 's711g', 'v443', 'ml14a', 's1111', 'g107', 'm55d', 'ml13b', 's413d', 'v446', 'g115', 's711ae', 'g117d', 'g119', 's413f', 's1231', 'ml13e', 'hw8', 'm55z', 's711c', 'm55j', 'ml13h', 's1210', 's1227', 's711af', 'ml18c', 'ml13k', 'ml19y', 's524ac', 's711ac', 'ml20c', 'ml18b', 'v474x', 'g117e', 'ml13i', 'g104', 's1204', 'hw6', 's524ad', 'ml14b', 's524ab', 'ml12', 'h44b', 'hw10', 's470a', 's524aa', 'ml13j', 'g117y', 'm55k', 'v474d', 's524ax', 's1207', 'ml23b', 'v444', 's1218', 'v474', 'ml22a', 's524ag', 'ml19a', 'g109', 's815g', 'g116', 'v441', 'hw5', 's1223', 'h41b', 's109a', 'h36c', 'ml13d', 'm55x', 's1221', 'm55e', 'm65h', 'v474b', 'ml15c', 'ml20b', 'ml13aa', 'ml17b', 's1206', 'ml19x', 'ml19z', 's1205', 'ml13c', 's1217', 'g112', 'ml19f', 'v474j', 's1222', 'm65x', 's524ah', 'v474g', 'v474i', 'ml13x', 'g106', 'g113', 'h35', 'g117c', 'idx97', 'ml15a', 'g117h', 's1112', 'v474a', 's1219', 'g101', 'ml19d', 'g117f', 'hw7', 'm55b', 'm65f', 'm65l', 'h36a', 's1114', 'ml22b', 'hw11', 's1229', 'v474h', 'g108', 'v444a', 'g105', 's711b', 's815f', 's1224'}
#     Additional columns (396): {'v543d', 'ecd31', 's1102a', 'sdv30bn', 's612q', 'mh3g', 'sgc8ef', 'v247l', 'mh3e', 'h67d', 'v509a', 's454a', 'h32nb', 'v483b', 's930c', 'm82', 'sgc8ce', 'v177', 'v472wb', 'sgc8cj', 'sgc8ci', 'v472we', 'v247a', 'mh20', 'v483a', 'v446a', 'v543g', 'v247h', 's621a', 's1102bh', 'm57na', 'sgc8cx', 'v414wb', 'mh10', 'v543a', 'v384h', 'v214a', 'ecd40', 'm57nd', 's1115b', 'v411s', 'sgc8ea', 'v471i', 'mh18a', 'mh5', 'sshort', 'ecd39', 'v635', 's1102bd', 'v414wd', 'sdv30bk', 'v384e', 'midxp', 'mh3d', 'm42k', 'v472v', 's509y', 'mh14', 'ecd23', 'v047', 'sgc8d', 'm13a', 'mh6', 's607aa', 'm57ne', 'mnb4', 's229', 'v3a10', 'mh12', 'sgc8cy', 'sdv30bx', 'mnb7c', 'sdv30bf', 'mh13', 'v414wa', 'v414wc', 'm81w', 'v446d', 'sdv30bj', 'v247x', 'sgc8eb', 'm81v', 'v172', 'sdv30ba', 'mh19', 's1102bg', 's1115c', 's631b', 'v508a', 'm81q', 'v367a', 'm81e', 's612t', 'v247y', 'm81d', 'h12ne', 'v247d', 'mh3c', 's626q', 'v169c', 'v248', 'mh15', 's1102bf', 'mh21b', 'mh18c', 'v413e', 'mh17e', 's932h', 's124', 'h67m', 'h26', 'v413as', 'mnb7i', 'mh21e', 'sgc8cm', 'ecd32', 'v3a08af', 's612s', 'sdv35a', 'm81u', 'mh16', 'v400', 's1102bi', 'mh7', 'sgc8ec', 'sgc8ek', 'v174m', 'm57nc', 's631l', 'm42g', 'h32nc', 'h37r', 'mnb7j', 'mh21a', 'v384i', 'v414we', 'sgc13b', 'v3a14', 'm81j', 'v247f', 'mnb7e', 'mnb7d', 'sm509d', 'ecd35', 's626s', 'ecd30', 'mh21c', 'mh22f', 'v246', 'v321a', 'sgc8cg', 'sgc8cl', 'mh22b', 'ecd37', 'h12nd', 'mnb7g', 'mh17a', 'sgc8ee', 'm81l', 's621b', 'sdv30bd', 'mh25', 'h12nc', 'sdv16d', 'h12nb', 'mh22e', 'sgc8a', 'h70a', 'v384g', 'idx94p', 'sgc8b', 'ecd27', 'mnb7a', 'v048', 'sgc8ck', 'm81b', 'ecd28', 's636dn', 'h67y', 'v413h', 'mh18b', 'm78p', 'sd509d', 'sd509y', 'v413i', 'm57nb', 's932g', 's1102bx', 'v511a', 'mnb5', 'sgc8el', 'h25y', 's612r', 'v384k', 'v247k', 'sdv30bi', 'sgc8cd', 'm81p', 's815i', 's1050f', 's1050c', 'm42f', 'sdv30bg', 'v249', 'v413g', 'mh3h', 'sdv30be', 'mnb7h', 'ecd38', 'v3a11', 's1105b', 'ecd36', 'v485a', 's631c', 'v413f', 'speduc', 'v174y', 'v247c', 'v471h', 'm81n', 's626t', 'h32nd', 'v472w', 's932f', 'v173', 'mnb12', 'mh9', 'v486', 'v485b', 'm81a', 's1050e', 'm81x', 'sgc8eg', 'sdv30bh', 'mh8', 'h25d', 'mh17d', 's1102ba', 'b21', 'sgc8cz', 's1105a', 's1050a', 'sgc8en', 'h32ne', 'v175', 'm81s', 'mnb6', 'm81k', 'v543e', 's1102bb', 'v3a13', 'ecd26', 'v472wd', 'm42m', 'm78l', 'mh3a', 'ecd24', 'm81c', 'sdv30bb', 'mh22c', 'sreduc', 's1102c', 'm42h', 'm81f', 'mh21d', 'mh23', 'm81nd', 'v247e', 'idxecd', 'v472wa', 'm81h', 'h70c', 'ecd21', 's1103b', 'm81o', 'sgc8ca', 'ecd33', 'h32na', 'mnb11', 's916a', 's1102be', 'm42j', 'm78k', 'v3a08ae', 'v247i', 'mh22a', 'm77a', 'sgc8ej', 'm81ne', 'v543b', 'v484b', 'h71', 'm42n', 'mh17c', 'v484a', 'sy509d', 'sdv30bm', 'sgc8ed', 'v3a12', 'v510a', 'sgc8ex', 'v176', 'mnb7z', 'mh3b', 'ecd22', 'sy509y', 'mnb1', 'v413bs', 'sgc8ch', 'sgc8cf', 'v245', 'h25m', 'v413s', 'sgc8ei', 'm81nc', 'v507a', 'v543x', 'sdv30a', 's631a', 'sdv30bz', 's1115a', 'm78o', 'm81t', 'm81m', 'v247b', 'v247g', 's1102bc', 'sdv30bl', 'bidxp', 'v384f', 'h70b', 'mnb7x', 'mh22d', 'sgc8em', 'h69', 'sgc8eh', 's930a', 'sm509y', 'ecd34', 'mh17b', 'm78m', 's1103a', 'mh3i', 's1050b', 'mnb3', 'm81i', 'm78n', 'h67', 'h37q', 'v543f', 'v471cs', 'mnb7f', 'h12na', 's631m', 'm42i', 's509d', 'v472wc', 'sgc8cc', 's815j', 'mnb7b', 'ecd29', 's446', 'mnb10', 's1050d', 'v247j', 'm81g', 'mh24', 'h68', 'm42l', 'idxecdp', 'v636', 'v544', 's607ba', 's615e', 'v384j', 'mh3f', 'm80', 'sgc8cb', 's528a', 'mh11', 'v542', 'sgc17b', 's1102bj', 'm81na', 's626r', 'sgc13a', 'mh18d', 'ecd25', 'm81r', 'v410as', 'v543c', 'mh21f', 's1500', 'sdv30bc', 'm81nb', 'sgc17a'}
# ET: Columns do not match
#     Similar columns (1115): {'v140', 'v474f', 'h21', 'm57a', 'h53d', 'v105', 'v525', 'hw56', 'ALT_GPS', 'v222', 'v469x', 'v028', 'v155', 'v413a', 'm65b', 'v411', 'v376', 'v745c', 'h8', 'v401', 'h12v', 'ml13y', 'g117j', 'hw12', 'ml14y', 'm57u', 'v104', 'v3a08f', 'v458', 'm2a', 'h36d', 'g111', 'v007', 'v507', 'v414i', 'v223', 'v472a', 'h58d', 'h50', 'h62d', 'm55f', 'v481g', 'm2d', 'hw53', 'v394', 'idx94', 'ml13g', 'v3a01', 'v045b', 'g117i', 'm57h', 'g114', 'v414u', 'g117g', 'm65c', 'v743a', 'v3a00i', 'v404', 'v013', 'm45', 'ml13p', 'h12w', 'h45', 'h43', 'ml14z', 'hw9', 'h12f', 'v204', 'ml13l', 'ml21c', 'v014', 'h15j', 'v231', 'hw70', 'h53', 'v413', 'ml15b', 'm57v', 'm1', 'm57m', 'v3a08d', 'm57p', 'm65i', 'm19', 'b9', 'h12t', 'bidx', 'v001', 'v602', 'm55l', 'v633c', 'h37aa', 'h36f', 'h37z', 'ml13da', 'v017', 'g122', 'v420', 'h6', 'h37c', 'awfacte', 'v153', 'm55m', 'm42d', 'v008', 'v474c', 'v440', 'v3a08ad', 'm8', 'ml16b', 'h13b', 'h62m', 'v731', 'v472h', 'h5', 'v476', 'h15g', 'h14', 'h10', 'g102', 's815e', 'h63', 'h13', 'h11b', 'h57', 'v633g', 'v467c', 'v471e', 'm47', 'h66', 'v502', 'v310', 'ml25a', 'h56', 'b18', 'v471b', 'ml14a', 'm55d', 'ml13b', 'v501', 'v504', 'g115', 'v168', 'g119', 'v191a', 'm39a', 'v319', 'hw18', 'ml13e', 'v131', 'v631', 'v510', 'v3a08r', 'v3a00y', 'v616', 'h80e', 'v032', 'h5m', 'v015', 'h37h', 'ml20c', 'h44b', 'v474x', 'v3a08q', 'g104', 'h31d', 'v364', 'b5', 'v137', 'm49a', 'h6d', 'v415', 'v107', 'm78b', 'v232', 'h32r', 'v3a00r', 'v474', 'h63m', 'v325a', 'h9m', 'g109', 's815g', 'h52y', 'h33', 'g116', 'h15c', 'v216', 'DHSID', 'v414s', 'h37n', 'v045c', 'v129', 'h32m', 'm55e', 'v472q', 'v3a00d', 'h59m', 'v463h', 'h32h', 'v3a00q', 'h37p', 'ADM1FIPSNA', 'ml20b', 'h60', 'm78d', 'v235', 'v466', 'm15', 'm27', 'country', 'v3a00n', 'h21a', 'h12p', 'v3a08o', 'v633b', 'v411a', 'awfactr', 'ml13c', 'v233', 'h55', 'ml19f', 'v474j', 'h6y', 'v511', 'h12y', 'v744a', 'v150', 'v471f', 'v315', 'v190', 'v3a08aa', 'v363', 'v472j', 'v535', 'm49g', 'h2y', 'v474i', 'v414j', 'h53y', 'v604', 'v134', 'b15', 'h32b', 'v508', 'v412b', 'v481c', 'm1a', 'v745b', 'v452a', 'h9', 'v472d', 'ADM1SALBCO', 'h37d', 'm36', 'v205', 'h15i', 'h50d', 'h32q', 'h37e', 'hidx', 'm70', 'v113', 'm49c', 'm44', 'v512', 'h7', 'm19a', 'v627', 'v418a', 'b3', 'ml22b', 'DHSYEAR', 'h9a', 'v416', 'v3a00t', 'v505', 'h32i', 'g108', 'v214', 'v454', 'v3a00e', 'v021', 'h3m', 'm2i', 'h32u', 'h63d', 'v715', 'v102', 'v482b', 'v743b', 'v3a08l', 'v456', 'm1b', 'm72', 'v203', 'v237', 'v481f', 'h40y', 'v3a04', 'm39', 'v477', 'ml17a', 'b20', 'hw71', 'h5y', 'v019a', 'h37b', 'v138', 'm55h', 'v3a00v', 'v467a', 'h57m', 'v414l', 'm10', 'm57i', 'h37m', 'ml101', 'v472t', 'SOURCE', 'v215', 'm61', 'v012', 'v3a08u', 'v224', 'v395', 'm65a', 'v474e', 'h37k', 'b1', 'v159', 'v414w', 'h50m', 'v413c', 'v3a00w', 'g103', 'g117x', 'm2e', 'm3c', 'h2', 'h64y', 'h12s', 'v026', 'v3a09a', 'v414f', 'h58m', 'h38', 'm48', 'v481x', 'v509', 'v3a03', 'v3a00z', 'b13', 'b16', 'm55i', 'v023', 'v3a09b', 'ml13n', 'awfactu', 'v472b', 'h57d', 'v634', 'v407', 'v406', 'm55a', 'ml24c', 'v506', 'v530', 'h60y', 'm3d', 'v626', 'idxml', 'ADM1SALBNA', 'h41a', 'v130', 'v239', 'v3a08s', 'v480', 'h15h', 'h39', 'v008a', 'g110', 'h60m', 'v379', 'v3a00b', 'v531', 'm64', 'h65y', 'h32n', 'h7y', 'v367', 'v459', 'v605', 'v463z', 'v457', 'ml18a', 'v745a', 'h58', 'v152', 'v141', 'b12', 'h66d', 'ADM1DHS', 'v228', 'm65d', 'v169a', 'h9ad', 'm78i', 'h54d', 'v125', 'v220', 'hw55', 'v359', 'v481a', 'h32v', 'v746', 'v120', 'v467k', 'm78g', 'v467j', 'h52m', 'v3a08m', 'v312', 'm2b', 'h60d', 'ml13m', 'g117b', 'v209', 'v472p', 'v453', 'h4m', 'v318', 'v414h', 'b8', 'ml0', 'b2', 'h2d', 'v115', 'm3m', 'm55z', 'b10', 'h32g', 'idx95', 'v743c', 'v240', 'v029', 'h15d', 'h62', 'ml13k', 'v414g', 'v025', 'v3a00c', 'h51m', 'v529', 'v3a08c', 'h12r', 'LONGNUM', 'm13', 'v437', 'ml13j', 'DHSREGCO', 'h55d', 'g117y', 'h55m', 'v474d', 'm2j', 'v464', 'hw17', 'h12m', 'v3a00j', 'v472n', 'v452b', 'h66y', 'ml22a', 'm66', 'v472l', 'v414n', 'v441', 'h32x', 'v463c', 'v539' ...
#     Missing columns (63): {'s1214', 's711ab', 's711aa', 's711g', 's1221', 's1211', 's1111', 's1216', 's711ae', 's1233', 's1206', 's413f', 's1231', 's1208', 's1213', 's1232', 's1205', 's1217', 's711c', 's711af', 's1209', 's1210', 's1227', 's904', 's1222', 's1228', 's524ac', 's524ah', 's524af', 's524ad', 's1204', 's1312a', 's470b', 's524ab', 's1202', 's470a', 's524aa', 's1203', 'idx97', 's524ax', 's470c', 's1207', 's1112', 's1219', 'sresid', 's1220', 's711ad', 's1218', 's1113', 's1226', 's524ag', 's1230', 's1212', 's524ae', 's1114', 's1229', 's1201', 's1215', 's1223', 's109a', 's711ac', 's815f', 's1224'}
#     Additional columns (191): {'s433a', 's412be', 's1420a', 'sh1', 's482', 's440a', 's1508p0', 'sd1508n2', 's1107a', 'sm508pa', 'sm508pb', 's437bb', 'sd1508n3', 's412db', 'sd1508r1', 'sy1508n2', 'sm1508p2', 's479e', 's412dc', 's1502', 's440bh', 'sviolen', 'sm508ma', 'sy1508p3', 's479b', 's412de', 'sm508nb', 'sd508ra', 's437bx', 's440be', 'sd1508d3', 'sy1508b', 's479g', 's924b', 's472', 's1508va', 's412dx', 'sm508rb', 's412da', 'sd508nb', 's440c', 'sd1508p1', 'sd1508d1', 's440ba', 'sd1508m1', 's440bf', 's1507b', 'sy1508d1', 's479x', 's924a', 's711cc', 's437bd', 's105m', 'sm1508n1', 'sd508pb', 's412ba', 's1508m1', 's1501', 's1508n1', 'sy1508p2', 'sm508da', 's412dd', 's326', 'sm508va', 's440bc', 's1508', 'sy1508n3', 's437ba', 'sm1508r1', 's433b', 's475', 'sd508pc', 'sfgm', 's412bg', 'sd1508va', 'sm508db', 's1508p2', 's412c', 's231m', 's238m', 'sd1508b', 'sm1508va', 's1107b', 'sd508nc', 's412bd', 'sm508ra', 's412bx', 'sd508dc', 's478', 'sd508da', 'sm1508m1', 's479f', 'sm508pd', 'sd1508p3', 'sm508dc', 's479c', 's104', 'sy1508d2', 'sm1508r2', 's440bx', 'h100', 's437a', 's477', 's1058', 's711d', 'sm1508p1', 's308m', 'sm1508d3', 's815d', 's1508n3', 'sm1508p0', 'sm1508n3', 's711a', 's309m', 's483', 'sy1508va', 'sintm', 's1107d', 's1508d3', 's1508d1', 'sd1508n1', 's109', 's1107e', 's414a', 's1508n2', 'sy1508d3', 's440bb', 'sy1508n1', 's434bx', 's1107c', 'sm508na', 's434a', 's474', 'sd508na', 'sy1508p0', 'sm508nc', 'sd1508d2', 's437bc', 's1507a', 's1508p1', 'sy1508r2', 'sm1508d2', 's479a', 'sd1508r2', 'sd508ba', 's440bd', 'sd508db', 's434bb', 'sm1508b', 's480', 's1056', 's434bd', 'sd1508p0', 's412df', 's412a', 's476', 's481', 'sd508ma', 'sd508va', 'sy1508m1', 's434ba', 's1508d2', 's1508r2', 'sd1508p2', 's434bc', 'sy1508p1', 'sy1508r1', 'sm1508n2', 's412bc', 's479h', 'sm1508p3', 's1507d', 's710m', 's412bb', 'sm508pc', 's479d', 'sd508rb', 'sd508pd', 's1507c', 's440bg', 's1508r1', 'sm1508d1', 's104a', 's1508b', 'sd508pa', 's473', 'sm508ba', 'sintd', 's1508p3', 's107', 's412bf'}
# NG: Columns do not match
#     Similar columns (1112): {'v140', 'v474f', 'h21', 'm57a', 'h53d', 'v105', 'v525', 'hw56', 'ALT_GPS', 'v222', 'v469x', 'v028', 'v155', 'v413a', 'm65b', 'v411', 'v376', 'v745c', 'h8', 'v401', 'h12v', 'ml13y', 'g117j', 'hw12', 'ml14y', 'm57u', 'v104', 'v3a08f', 'v458', 'm2a', 'h36d', 'g111', 'v007', 'v507', 'v414i', 'v223', 'v472a', 'h58d', 'h50', 'h62d', 'm55f', 'v481g', 'm2d', 'hw53', 'v394', 'idx94', 'ml13g', 'v3a01', 'v045b', 'g117i', 'm57h', 'g114', 'v414u', 'g117g', 'm65c', 'v743a', 'v3a00i', 'v404', 'v013', 'm45', 'ml13p', 'h12w', 'h45', 'h43', 'ml14z', 'hw9', 'h12f', 'v204', 'ml13l', 'ml21c', 'v014', 'h15j', 'v231', 'hw70', 'h53', 'v413', 'ml15b', 'm57v', 'm1', 'm57m', 'v3a08d', 'm57p', 'm65i', 'm19', 'b9', 'h12t', 'bidx', 'v001', 'v602', 'm55l', 'v633c', 'h37aa', 'h36f', 'h37z', 'ml13da', 'v017', 'g122', 'v420', 'h6', 'h37c', 'awfacte', 'v153', 'm55m', 'm42d', 'v008', 'v474c', 'v440', 'v3a08ad', 'm8', 'ml16b', 'h13b', 'h62m', 'v731', 'v472h', 'h5', 'v476', 'h15g', 'h14', 'h10', 'g102', 's815e', 'h63', 'h13', 'h11b', 'h57', 'v633g', 'v467c', 'v471e', 'm47', 'h66', 'v502', 'v310', 'ml25a', 'h56', 'b18', 'v471b', 'ml14a', 'm55d', 'ml13b', 'v501', 'v504', 'g115', 'v168', 'g119', 'v191a', 'm39a', 'v319', 'hw18', 'ml13e', 'v131', 'v631', 'v510', 'v3a08r', 'v3a00y', 'v616', 'h80e', 'v032', 'h5m', 'v015', 'h37h', 'ml20c', 'v474x', 'v3a08q', 'g104', 'h31d', 'v364', 'b5', 'v137', 'm49a', 'h6d', 'v415', 'v107', 'm78b', 'v232', 'h32r', 'v3a00r', 'v474', 'h63m', 'v325a', 'h9m', 'g109', 's815g', 'h52y', 'h33', 'g116', 'h15c', 'v216', 'DHSID', 'v414s', 'h37n', 'v045c', 'v129', 'h32m', 'm55e', 'v472q', 'v3a00d', 'h59m', 'v463h', 'h32h', 'v3a00q', 'h37p', 'ADM1FIPSNA', 'ml20b', 'h60', 'm78d', 'v235', 'v466', 'm15', 'm27', 'country', 'v3a00n', 'h21a', 'h12p', 'v3a08o', 'v633b', 'v411a', 'awfactr', 'ml13c', 'v233', 'h55', 'ml19f', 'v474j', 'h6y', 'v511', 'h12y', 'v744a', 'v150', 'v471f', 'v315', 'v190', 'v3a08aa', 'v363', 'v472j', 'v535', 'm49g', 'h2y', 'v474i', 'v414j', 'h53y', 'v604', 'v134', 'b15', 'h32b', 'v508', 'v412b', 'v481c', 'm1a', 'v745b', 'v452a', 'h9', 'v472d', 'ADM1SALBCO', 'h37d', 'm36', 'v205', 'h15i', 'h50d', 'h32q', 'h37e', 'hidx', 'm70', 'v113', 'm49c', 'm44', 'v512', 'h7', 'm19a', 'v627', 'v418a', 'b3', 'ml22b', 'DHSYEAR', 'h9a', 'v416', 'v3a00t', 'v505', 'h32i', 'g108', 'v214', 'v454', 'v3a00e', 'v021', 'h3m', 'm2i', 'h32u', 'h63d', 'v715', 'v102', 'v482b', 'v743b', 'v3a08l', 'v456', 'm1b', 'm72', 'v203', 'v237', 'v481f', 'h40y', 'v3a04', 'm39', 'v477', 'ml17a', 'b20', 'hw71', 'h5y', 'v019a', 'h37b', 'v138', 'm55h', 'v3a00v', 'v467a', 'h57m', 'v414l', 'm10', 'm57i', 'h37m', 'ml101', 'v472t', 'SOURCE', 'v215', 'm61', 'v012', 'v3a08u', 'v224', 'v395', 'm65a', 'v474e', 'h37k', 'b1', 'v159', 'v414w', 'h50m', 'v413c', 'v3a00w', 'g103', 'g117x', 'm2e', 'm3c', 'h2', 'h64y', 'h12s', 'v026', 'v3a09a', 'v414f', 'h58m', 'h38', 'm48', 'v481x', 'v509', 'v3a03', 'v3a00z', 'b13', 'b16', 'm55i', 'v023', 'v3a09b', 'ml13n', 'awfactu', 'v472b', 'h57d', 'v634', 'v407', 'v406', 'm55a', 'ml24c', 'v506', 'v530', 'h60y', 'm3d', 'v626', 'idxml', 'ADM1SALBNA', 'h41a', 'v130', 'v239', 'v3a08s', 'v480', 'h15h', 'h39', 'v008a', 'g110', 'h60m', 'v379', 'v3a00b', 'v531', 'm64', 'h65y', 'h32n', 'h7y', 'v367', 'v459', 'v605', 'v463z', 'v457', 'ml18a', 'v745a', 'h58', 'v152', 'v141', 'b12', 'h66d', 'ADM1DHS', 'v228', 'm65d', 'v169a', 'h9ad', 'm78i', 'h54d', 'v125', 'v220', 'hw55', 'v359', 'v481a', 'h32v', 'v746', 'v120', 'v467k', 'm78g', 'v467j', 'h52m', 'v3a08m', 'v312', 'm2b', 'h60d', 'ml13m', 'g117b', 'v209', 'v472p', 'v453', 'h4m', 'v318', 'v414h', 'b8', 'ml0', 'b2', 'h2d', 'v115', 'm3m', 'm55z', 'b10', 'h32g', 'v743c', 'v240', 'v029', 'h15d', 'h62', 'ml13k', 'v414g', 'v025', 'v3a00c', 'h51m', 'v529', 'v3a08c', 'h12r', 'LONGNUM', 'm13', 'v437', 'ml13j', 'DHSREGCO', 'h55d', 'g117y', 'h55m', 'v474d', 'm2j', 'v464', 'hw17', 'h12m', 'v3a00j', 'v472n', 'v452b', 'h66y', 'ml22a', 'm66', 'v472l', 'v414n', 'v441', 'h32x', 'v463c', 'v539', 'v471d', 'v463b ...
#     Missing columns (66): {'s1214', 's711ab', 's711aa', 's711g', 's1221', 's1211', 's1111', 's413d', 's1216', 's711ae', 's1233', 's1206', 's413f', 's1231', 's1208', 's1213', 's1232', 's1205', 's1217', 's711c', 'idx95', 's711af', 's1209', 's1210', 's1227', 's904', 's1222', 's1228', 's711ac', 's524ac', 's524ah', 's524af', 's524ad', 's1204', 's1312a', 's470b', 's524ab', 's1202', 's470a', 's524aa', 's1203', 'idx97', 's524ax', 's470c', 's1207', 's1112', 's1219', 'sresid', 's1220', 's711ad', 's1218', 's1113', 's1226', 's524ag', 's1230', 's1212', 's524ae', 's1114', 's1229', 's1201', 's1215', 's1223', 's109a', 's108', 's711b', 's1224'}
#     Additional columns (109): {'s433a', 's815h', 's434ix', 's430ej', 's1108ac', 's434ie', 's429a', 's653v', 's430g', 's434l', 's430ef', 's430eg', 's430ec', 's1108ai', 's653i', 's1306', 's1310', 's1205aa', 's430eh', 's653j', 's1205ba', 's1308f', 's430ea', 's653l', 's430el', 's430c', 's1306a', 's430ek', 's653k', 's1302', 's220bd', 's1308g', 's1305', 's1308x', 's434ic', 's653h', 's1308d', 's1301', 's434k', 's430b', 's653p', 's1108bc', 's1308h', 's434if', 's653o', 's430ez', 's1308b', 's430d', 's1205b', 's1108bf', 's430ei', 's1108af', 's1108ab', 's1108ad', 's430a', 's434h', 's653b', 's653q', 's1108bd', 's1311', 's1205ca', 's434c', 's1304', 's653r', 's434b', 's434id', 's816b', 'sstate', 's653e', 's816c', 's220bm', 's1307', 's434ia', 's434f', 's430ed', 's1308a', 's1303', 'idx92', 's434ig', 's434e', 's430ee', 's653n', 's653f', 's816e', 's653d', 's1205da', 's816d', 's653s', 's1308e', 's430eb', 's1308c', 's653c', 's434ib', 's815i', 's653m', 's1108ba', 's434iz', 's653u', 's1309', 's1313', 's434g', 's1312', 's653t', 's653a', 's816x', 's430ex', 's653g', 's220by', 's816a'}
# ZW: Columns do not match
#     Similar columns (1074): {'v140', 'v474f', 'h21', 'm57a', 'h53d', 'v105', 'v525', 'hw56', 'ALT_GPS', 'v222', 'v469x', 'v028', 'v155', 'v413a', 'm65b', 'v411', 'v376', 'v745c', 'h8', 'v401', 'h12v', 'ml13y', 'hw12', 'ml14y', 'm57u', 'v104', 'v3a08f', 'v458', 'm2a', 'h36d', 'v007', 'v507', 'v414i', 'v223', 'v472a', 'h58d', 'h50', 'h62d', 'm55f', 'v481g', 'm2d', 'hw53', 'v394', 'idx94', 'ml13g', 'v3a01', 'v045b', 'm57h', 'v414u', 'm65c', 'v743a', 'v3a00i', 'v404', 'v013', 'm45', 'ml13p', 'h12w', 'h45', 'h43', 'ml14z', 'hw9', 'h12f', 'v204', 'ml13l', 'ml21c', 'v014', 'h15j', 'v231', 'hw70', 'h53', 'v413', 'ml15b', 'm57v', 'm1', 'm57m', 'v3a08d', 'm57p', 'm65i', 'm19', 'b9', 'h12t', 'bidx', 'v001', 'v602', 'm55l', 'v633c', 'h37aa', 'h36f', 'h37z', 'ml13da', 'v017', 'v420', 'h6', 'h37c', 'awfacte', 'v153', 'm55m', 'm42d', 'v008', 'v474c', 'v440', 'v3a08ad', 'm8', 'ml16b', 'h13b', 'h62m', 'v731', 'v472h', 'h5', 'v476', 'h15g', 'h14', 'h10', 's815e', 'h63', 'h13', 'h11b', 'h57', 'v633g', 'v467c', 'v471e', 'm47', 'h66', 'v502', 'v310', 'ml25a', 'h56', 'b18', 'v471b', 'ml14a', 'm55d', 'ml13b', 'v501', 'v504', 'v168', 'v191a', 'm39a', 'v319', 'hw18', 'ml13e', 'v131', 'v631', 'v510', 'v3a08r', 'v3a00y', 'v616', 'h80e', 'v032', 'h5m', 'v015', 'h37h', 'ml20c', 'v474x', 'v3a08q', 'h31d', 'v364', 'b5', 'v137', 'm49a', 'h6d', 'v415', 'v107', 'm78b', 'v232', 'h32r', 'v3a00r', 'v474', 'h63m', 'v325a', 'h9m', 'h52y', 'h33', 'h15c', 'v216', 'DHSID', 'v414s', 'h37n', 'v045c', 'v129', 'h32m', 'm55e', 'v472q', 'v3a00d', 'h59m', 'v463h', 'h32h', 'v3a00q', 'h37p', 'ADM1FIPSNA', 'ml20b', 'h60', 'm78d', 'v235', 'v466', 'm15', 'm27', 'country', 'v3a00n', 'h21a', 'h12p', 'v3a08o', 'v633b', 'v411a', 'awfactr', 'ml13c', 'v233', 'h55', 'ml19f', 'v474j', 'h6y', 'v511', 'h12y', 'v744a', 'v150', 'v471f', 'v315', 'v190', 'v3a08aa', 'v363', 'v472j', 'v535', 'm49g', 'h2y', 'v474i', 'v414j', 'h53y', 'v604', 'v134', 'b15', 'h32b', 'v508', 'v412b', 'v481c', 'm1a', 'v745b', 'v452a', 'h9', 'v472d', 'ADM1SALBCO', 'h37d', 'm36', 'v205', 'h15i', 'h50d', 'h32q', 'h37e', 'hidx', 'm70', 'v113', 'm49c', 'm44', 'v512', 'h7', 'm19a', 'v627', 'v418a', 'b3', 'ml22b', 'DHSYEAR', 'h9a', 'v416', 'v3a00t', 'v505', 'h32i', 'v214', 'v454', 'v3a00e', 'v021', 'h3m', 'm2i', 'h32u', 'h63d', 'v715', 'v102', 'v482b', 'v743b', 'v3a08l', 'v456', 'm1b', 'm72', 'v203', 'v237', 'v481f', 'm39', 'v3a04', 'h40y', 'v477', 'ml17a', 'b20', 'hw71', 'h5y', 'v019a', 'h37b', 'v138', 'm55h', 'v3a00v', 'v467a', 'h57m', 'v414l', 'm10', 'm57i', 'h37m', 'ml101', 'v472t', 'SOURCE', 'v215', 'm61', 'v012', 'v3a08u', 'v224', 'v395', 'm65a', 'v474e', 'h37k', 'b1', 'v159', 'v414w', 'h50m', 'v413c', 'v3a00w', 'm2e', 'm3c', 'h2', 'h64y', 'h12s', 'v026', 'v3a09a', 'v414f', 'h58m', 'h38', 'm48', 'v481x', 'v509', 'v3a03', 'v3a00z', 'b13', 'b16', 'm55i', 'v023', 'v3a09b', 'ml13n', 'awfactu', 'v472b', 'h57d', 'v634', 'v407', 'v406', 'm55a', 'ml24c', 'v506', 'v530', 'h60y', 'm3d', 'v626', 'idxml', 'ADM1SALBNA', 'h41a', 'v130', 'v239', 'v3a08s', 'v480', 'h15h', 'h39', 'v008a', 'h60m', 'v379', 'v3a00b', 'v531', 'm64', 'h65y', 'h32n', 'h7y', 'v367', 'v459', 'v605', 'v463z', 'v457', 'ml18a', 'v745a', 'h58', 'v152', 'v141', 'b12', 'h66d', 'ADM1DHS', 'v228', 'm65d', 'v169a', 'h9ad', 'm78i', 'h54d', 'v125', 'v220', 'hw55', 'v359', 'v481a', 'h32v', 'v746', 'v120', 'v467k', 'm78g', 'v467j', 'h52m', 'v3a08m', 'v312', 'm2b', 'h60d', 'ml13m', 'v209', 'v472p', 'v453', 'h4m', 'v318', 'v414h', 'b8', 'ml0', 'b2', 'h2d', 'v115', 'm3m', 'm55z', 'b10', 'h32g', 'v743c', 'v240', 'v029', 'h15d', 'h62', 'ml13k', 'v414g', 'v025', 'v3a00c', 'h51m', 'v529', 'v3a08c', 'h12r', 'LONGNUM', 'm13', 'v437', 'ml13j', 'DHSREGCO', 'h55d', 'h55m', 'v474d', 'm2j', 'v464', 'hw17', 'h12m', 'v3a00j', 'v472n', 'v452b', 'h66y', 'ml22a', 'm66', 'v472l', 'v414n', 'v441', 'h32x', 'v463c', 'v539', 'v471d', 'v463b', 'v472m', 'h36c', 'h51', 'm55x', 'v704', 'h52', 'v384b', 'v3a08t', 'v322', 'h33d', 'caseid', 'v3a08h', 'm65h', 'm3k', 'h61', 'v011', 'h32c', 'm2l', 'v621', ' ...
#     Missing columns (104): {'g117j', 'g111', 's1208', 's1213', 's1232', 'g121', 's1202', 'g117i', 's1203', 'g114', 'g117g', 's470c', 'sresid', 'g123', 's711ad', 'g103', 'g117x', 's1230', 's1212', 's524ae', 's1215', 's108', 'g117a', 's1214', 's711ab', 's711aa', 's1211', 'g118', 's1216', 's1233', 's1209', 's1228', 's904', 'g110', 'g122', 's524af', 's470b', 's1312a', 'gidx', 's1220', 's1113', 's1226', 'g102', 's1201', 'g124', 'g100', 'g117b', 's711g', 's1111', 'g107', 's413d', 'g115', 's711ae', 'g117d', 'g119', 's413f', 's1231', 's711c', 'idx95', 's711af', 's1210', 's1227', 's711ac', 's524ac', 'g117e', 'g104', 's1204', 's524ad', 's524ab', 's470a', 's524aa', 'g117y', 's524ax', 's1207', 's1218', 's524ag', 'g109', 's815g', 'g116', 's1223', 's109a', 's1221', 's1206', 's1205', 's1217', 'g112', 's1222', 's524ah', 'g106', 'g113', 'g117c', 'idx97', 'g117h', 's1112', 's1219', 'g101', 'g117f', 's1114', 's1229', 'g108', 'g105', 's711b', 's815f', 's1224'}
#     Additional columns (59): {'h100', 's121m', 's1108ab', 's1108ac', 's730ev', 's121o', 's721aa', 's730bx', 's816', 's307', 's121r', 's1110c', 's121q', 's730f', 's730bu', 's730c', 's1108acy', 's1108acm', 's1108aa', 's121p', 's121h', 's1110y', 's1007c', 's121g', 's730ew', 's1110b', 's1007b', 's121l', 's730eu', 's721ab', 's1110cc', 's730et', 's1108acd', 's1110dd', 's421d', 's1034a', 's1110x', 's721bc', 's932f', 's730bw', 's121n', 's721ba', 's730bt', 's730br', 's421c', 's1007a', 's730bv', 's121j', 's1110bb', 's721bb', 's1110a', 's121k', 's421a', 's1110aa', 's730ex', 's721ac', 's730er', 's121i', 's1110d'}
# UG: Columns do not match
#     Similar columns (1075): {'v140', 'v474f', 'h21', 'm57a', 'h53d', 'v105', 'v525', 'hw56', 'ALT_GPS', 'v222', 'v469x', 'v028', 'v155', 'v413a', 'm65b', 'v411', 'v376', 'v745c', 'h8', 'v401', 'h12v', 'ml13y', 'hw12', 'ml14y', 'm57u', 'v104', 'v3a08f', 'v458', 'm2a', 'h36d', 'v007', 'v507', 'v414i', 'v223', 'v472a', 'h58d', 'h50', 'h62d', 'm55f', 'v481g', 'm2d', 'hw53', 'v394', 'idx94', 'ml13g', 'v3a01', 'v045b', 'm57h', 'v414u', 'm65c', 'v743a', 'v3a00i', 'v404', 'v013', 'm45', 'ml13p', 'h12w', 'h45', 'h43', 'ml14z', 'hw9', 'h12f', 'v204', 'ml13l', 'ml21c', 'v014', 'h15j', 'v231', 'hw70', 'h53', 'v413', 'ml15b', 'm57v', 'm1', 'm57m', 'v3a08d', 'm57p', 'm65i', 'm19', 'b9', 'h12t', 'bidx', 'v001', 'v602', 'm55l', 'v633c', 'h37aa', 'h36f', 'h37z', 'ml13da', 'v017', 'v420', 'h6', 'h37c', 'awfacte', 'v153', 'm55m', 'm42d', 'v008', 'v474c', 'v440', 'v3a08ad', 'm8', 'ml16b', 'h13b', 'h62m', 'v731', 'v472h', 'h5', 'v476', 'h15g', 'h14', 'h10', 'h63', 'h13', 'h11b', 'h57', 'v633g', 'v467c', 'v471e', 'm47', 'h66', 'v502', 'v310', 'ml25a', 'h56', 'b18', 'v471b', 'ml14a', 'm55d', 'ml13b', 'v501', 'v504', 'v168', 'v191a', 'm39a', 'v319', 'hw18', 'ml13e', 'v131', 'v631', 'v510', 'v3a08r', 'v3a00y', 'v616', 'h80e', 'v032', 'h5m', 'v015', 'h37h', 'ml20c', 'v474x', 'v3a08q', 'h31d', 'v364', 'b5', 'v137', 'm49a', 'h6d', 'v415', 'v107', 'm78b', 'v232', 'h32r', 'v3a00r', 'v474', 'h63m', 'v325a', 'h9m', 'h52y', 'h33', 'h15c', 'v216', 'DHSID', 'v414s', 'h37n', 'v045c', 'v129', 'h32m', 'm55e', 'v472q', 'v3a00d', 'h59m', 'v463h', 'h32h', 'v3a00q', 'h37p', 'ADM1FIPSNA', 'ml20b', 'h60', 'm78d', 'v235', 'v466', 'm15', 'm27', 'country', 'v3a00n', 'h21a', 'h12p', 'v3a08o', 'v633b', 'v411a', 'awfactr', 'ml13c', 'v233', 'h55', 'ml19f', 'v474j', 'h6y', 'v511', 'h12y', 'v744a', 'v150', 'v471f', 'v315', 'v190', 'v3a08aa', 'v363', 'v472j', 'v535', 'm49g', 'h2y', 'v474i', 'v414j', 'h53y', 'v604', 'v134', 'b15', 'h32b', 'v508', 'v412b', 'v481c', 'm1a', 'v745b', 'v452a', 'h9', 'v472d', 'ADM1SALBCO', 'h37d', 'm36', 'v205', 'h15i', 'h50d', 'h32q', 'h37e', 'hidx', 'm70', 'v113', 'm49c', 'm44', 'v512', 'h7', 'm19a', 'v627', 'v418a', 'b3', 'ml22b', 'DHSYEAR', 'h9a', 'v416', 'v3a00t', 'v505', 'h32i', 'v214', 'v454', 'v3a00e', 'v021', 'h3m', 'm2i', 'h32u', 'h63d', 'v715', 'v102', 'v482b', 'v743b', 'v3a08l', 'v456', 'm1b', 'm72', 'v203', 'v237', 'v481f', 'm39', 'v3a04', 'h40y', 'v477', 'ml17a', 'b20', 'hw71', 'h5y', 'v019a', 'h37b', 'v138', 'm55h', 'v3a00v', 'v467a', 'h57m', 'v414l', 'm10', 'm57i', 'h37m', 'ml101', 'v472t', 'SOURCE', 'v215', 'm61', 'v012', 'v3a08u', 'v224', 'v395', 'm65a', 'v474e', 'h37k', 'b1', 'v159', 'v414w', 'h50m', 'v413c', 'v3a00w', 'm2e', 'm3c', 'h2', 'h64y', 'h12s', 'v026', 'v3a09a', 'v414f', 'h58m', 'h38', 'm48', 'v481x', 'v509', 'v3a03', 'v3a00z', 'b13', 'b16', 'm55i', 'v023', 'v3a09b', 'ml13n', 'awfactu', 'v472b', 'h57d', 'v634', 'v407', 'v406', 'm55a', 'ml24c', 'v506', 'v530', 'h60y', 'm3d', 'v626', 'idxml', 'ADM1SALBNA', 'h41a', 'v130', 'v239', 'v3a08s', 'v480', 'h15h', 'h39', 'v008a', 'h60m', 'v379', 'v3a00b', 'v531', 'm64', 'h65y', 'h32n', 'h7y', 'v367', 'v459', 'v605', 'v463z', 'v457', 'ml18a', 'v745a', 'h58', 'v152', 'v141', 'b12', 'h66d', 'ADM1DHS', 'v228', 'm65d', 'v169a', 'h9ad', 'm78i', 'h54d', 'v125', 'v220', 'hw55', 'v359', 'v481a', 'h32v', 'v746', 'v120', 'v467k', 'm78g', 'v467j', 'h52m', 'v3a08m', 'v312', 'm2b', 'h60d', 'ml13m', 'v209', 'v472p', 'v453', 'h4m', 'v318', 'v414h', 'b8', 'ml0', 'b2', 'h2d', 'v115', 'm3m', 'm55z', 'b10', 'h32g', 'v743c', 'v240', 'v029', 'h15d', 'h62', 'ml13k', 'v414g', 'v025', 'v3a00c', 'h51m', 'v529', 'v3a08c', 'h12r', 'LONGNUM', 'm13', 'v437', 'ml13j', 'DHSREGCO', 'h55d', 'h55m', 'v474d', 'm2j', 'v464', 'hw17', 'h12m', 'v3a00j', 'v472n', 'v452b', 'h66y', 'ml22a', 'm66', 'v472l', 'v414n', 'v441', 'h32x', 'v463c', 'v539', 'v471d', 'v463b', 'v472m', 'h36c', 'h51', 'm55x', 'v704', 'h52', 'v384b', 'v3a08t', 'v322', 'h33d', 'caseid', 'v3a08h', 'm65h', 'm3k', 'h61', 'v011', 'h32c', 'm2l', 'v621', 'm6', 'v24 ...
#     Missing columns (103): {'g117j', 'g111', 's1208', 's1213', 's1232', 'g121', 's1202', 'g117i', 's1203', 'g114', 'g117g', 's470c', 'sresid', 'g123', 's711ad', 'g103', 'g117x', 's1230', 's1212', 's524ae', 's1215', 'g117a', 's1214', 's711ab', 's711aa', 's1211', 'g118', 's1216', 's1233', 's1209', 's1228', 'g110', 'g122', 's524af', 's470b', 's1312a', 'gidx', 's1220', 's815e', 's1113', 's1226', 'g102', 's1201', 'g124', 'g100', 'g117b', 's711g', 's1111', 'g107', 's413d', 'g115', 's711ae', 'g117d', 'g119', 's413f', 's1231', 's711c', 'idx95', 's711af', 's1210', 's1227', 's711ac', 's524ac', 'g117e', 'g104', 's1204', 's524ad', 's524ab', 's470a', 's524aa', 'g117y', 's524ax', 's1207', 's1218', 's524ag', 'g109', 's815g', 'g116', 's1223', 's109a', 's1221', 's1206', 's1205', 's1217', 'g112', 's1222', 's524ah', 'g106', 'g113', 'g117c', 'idx97', 'g117h', 's1112', 's1219', 'g101', 'g117f', 's1114', 's1229', 'g108', 'g105', 's711b', 's815f', 's1224'}
#     Additional columns (81): {'s730g', 'sec18', 'sdv23c', 's121m', 'sdistrict', 'sdv23gb', 'sec10fb', 'sec10cx', 'sec6b', 's730h', 'sdv23d', 's121l', 'sec15', 's121j', 'sdv23ga', 'sec10ab', 's1110a', 'sec10bx', 's121i', 'sec4', 'sec10ax', 's102', 's122g', 'sec5c', 's701ac', 'sec2', 'sec10aa', 's730a', 's1108a', 'sec10cy', 'sec12', 's121k', 'sec10ca', 's104', 's730e', 'sec5a', 's730d', 'sec13', 'sec10ey', 'sec14', 'sdv23b', 'sec10ex', 'scapimgr', 's122e', 'sec10cb', 'sec10da', 's121g', 'sec16', 'sec10fy', 'sec10ba', 'sec11', 'sdv23f', 'sec17', 's701aa', 'sec10fx', 's701ab', 'sec19', 'sec5b', 's422a', 's122h', 'sec20', 'sec10dy', 's730f', 's730c', 'sec10dx', 'sec10db', 's121h', 'sec10by', 'sdv23a', 'sec6a', 'sdv23e', 'sec10fa', 'sec8', 'sec9', 'sec10ea', 's103', 'sec10eb', 's730i', 's730b', 'sec10ay', 'sec10bb'}
# BU: Columns do not match
#     Similar columns (1079): {'v140', 'v474f', 'h21', 'm57a', 'h53d', 'v105', 'v525', 'hw56', 'ALT_GPS', 'v222', 'v469x', 'v028', 'v155', 'v413a', 'm65b', 'v411', 'v376', 'v745c', 'h8', 'v401', 'h12v', 'ml13y', 'hw12', 'ml14y', 'm57u', 'v104', 'v3a08f', 'v458', 'm2a', 'h36d', 'v007', 'v507', 'v414i', 'v223', 'v472a', 'h58d', 'h50', 'h62d', 'm55f', 'v481g', 'm2d', 'hw53', 'v394', 'idx94', 'ml13g', 'v3a01', 'v045b', 'm57h', 'v414u', 'm65c', 'v743a', 'v3a00i', 'v404', 'v013', 'm45', 'ml13p', 'h12w', 'h45', 'h43', 'ml14z', 'hw9', 'h12f', 'v204', 'ml13l', 'ml21c', 'v014', 'h15j', 'v231', 'hw70', 'h53', 'v413', 'ml15b', 'm57v', 'm1', 'm57m', 'v3a08d', 'm57p', 'm65i', 'm19', 'b9', 'h12t', 'bidx', 'v001', 'v602', 'm55l', 'v633c', 'h37aa', 'h36f', 'h37z', 'ml13da', 'v017', 'v420', 'h6', 'h37c', 'awfacte', 'v153', 'm55m', 'm42d', 'v008', 'v474c', 'v440', 'v3a08ad', 'm8', 'ml16b', 'h13b', 'h62m', 'v731', 'v472h', 'h5', 'v476', 'h15g', 'h14', 'h10', 'h63', 'h13', 'h11b', 'h57', 'v633g', 'v467c', 'v471e', 'm47', 'h66', 'v502', 'v310', 'ml25a', 'h56', 'b18', 'v471b', 'ml14a', 'm55d', 'ml13b', 'v501', 'v504', 'v168', 'v191a', 'm39a', 'v319', 'hw18', 'ml13e', 'v131', 'v631', 'v510', 'v3a08r', 'v3a00y', 'v616', 'h80e', 'v032', 'h5m', 'v015', 'h37h', 'ml20c', 'v474x', 'v3a08q', 'h31d', 'v364', 'b5', 'v137', 'm49a', 'h6d', 'v415', 'v107', 'm78b', 'v232', 'h32r', 'v3a00r', 'v474', 'h63m', 'v325a', 'h9m', 'h52y', 'h33', 'h15c', 'v216', 'DHSID', 'v414s', 'h37n', 'v045c', 'v129', 'h32m', 'm55e', 'v472q', 'v3a00d', 'h59m', 'v463h', 'h32h', 'v3a00q', 'h37p', 'ADM1FIPSNA', 'ml20b', 'h60', 'm78d', 'v235', 'v466', 'm15', 'm27', 'country', 'v3a00n', 'h21a', 'h12p', 'v3a08o', 'v633b', 'v411a', 'awfactr', 'ml13c', 'v233', 'h55', 'ml19f', 'v474j', 'h6y', 'v511', 'h12y', 'v744a', 'v150', 'v471f', 'v315', 'v190', 'v3a08aa', 'v363', 'v472j', 'v535', 'm49g', 'h2y', 'v474i', 'v414j', 'h53y', 'v604', 'v134', 'b15', 'h32b', 'v508', 'v412b', 'v481c', 'm1a', 'v745b', 'v452a', 'h9', 'v472d', 'ADM1SALBCO', 'h37d', 'm36', 'v205', 'h15i', 'h50d', 'h32q', 'h37e', 'hidx', 'm70', 'v113', 'm49c', 'm44', 'v512', 'h7', 'm19a', 'v627', 'v418a', 'b3', 'ml22b', 'DHSYEAR', 'h9a', 'v416', 'v3a00t', 'v505', 'h32i', 'v214', 'v454', 'v3a00e', 'v021', 'h3m', 'm2i', 'h32u', 'h63d', 'v715', 'v102', 'v482b', 'v743b', 'v3a08l', 'v456', 'm1b', 'm72', 'v203', 'v237', 'v481f', 'm39', 'v3a04', 'h40y', 'v477', 'ml17a', 'b20', 'hw71', 'h5y', 'v019a', 'h37b', 'v138', 'm55h', 'v3a00v', 'v467a', 'h57m', 'v414l', 'm10', 'm57i', 'h37m', 'ml101', 'v472t', 'SOURCE', 'v215', 'm61', 'v012', 'v3a08u', 'v224', 'v395', 'm65a', 'v474e', 'h37k', 'b1', 'v159', 'v414w', 'h50m', 'v413c', 'v3a00w', 'm2e', 'm3c', 'h2', 'h64y', 'h12s', 'v026', 'v3a09a', 'v414f', 'h58m', 'h38', 'm48', 'v481x', 'v509', 'v3a03', 'v3a00z', 'b13', 'b16', 'm55i', 'v023', 'v3a09b', 'ml13n', 'awfactu', 'v472b', 'h57d', 'v634', 'v407', 'v406', 'm55a', 'ml24c', 'v506', 'v530', 'h60y', 'm3d', 'v626', 'idxml', 'ADM1SALBNA', 'h41a', 'v130', 'v239', 'v3a08s', 'v480', 'h15h', 'h39', 'v008a', 'h60m', 'v379', 'v3a00b', 'v531', 'm64', 'h65y', 'h32n', 'h7y', 'v367', 'v459', 'v605', 'v463z', 'v457', 'ml18a', 'v745a', 'h58', 'v152', 'v141', 'b12', 'h66d', 'ADM1DHS', 'v228', 'm65d', 'v169a', 'h9ad', 'm78i', 'h54d', 'v125', 's1113', 'v220', 'hw55', 'v359', 'v481a', 'h32v', 'v746', 'v120', 'v467k', 'm78g', 'v467j', 'h52m', 'v3a08m', 'v312', 'm2b', 'h60d', 'ml13m', 'v209', 'v472p', 'v453', 'h4m', 'v318', 'v414h', 'b8', 'ml0', 'b2', 'h2d', 'v115', 'm3m', 'm55z', 'b10', 'h32g', 'idx95', 'v743c', 'v240', 'v029', 'h15d', 'h62', 'ml13k', 'v414g', 'v025', 'v3a00c', 'h51m', 'v529', 'v3a08c', 'h12r', 'LONGNUM', 'm13', 'v437', 'ml13j', 'DHSREGCO', 'h55d', 'h55m', 'v474d', 'm2j', 'v464', 'hw17', 'h12m', 'v3a00j', 'v472n', 'v452b', 'h66y', 'ml22a', 'm66', 'v472l', 'v414n', 'v441', 'h32x', 'v463c', 'v539', 'v471d', 'v463b', 'v472m', 'h36c', 'h51', 'm55x', 'v704', 'h52', 'v384b', 'v3a08t', 'v322', 'h33d', 'caseid', 'v3a08h', 'm65h', 'm3k', 'h61', 'v011', 'h32c', 'm2l',  ...
#     Missing columns (99): {'g117j', 'g111', 's1208', 's1213', 's1232', 'g121', 's1202', 'g117i', 's1203', 'g114', 'g117g', 's470c', 'sresid', 'g123', 's711ad', 'g103', 'g117x', 's1230', 's1212', 's524ae', 's1215', 'g117a', 's1214', 's711ab', 's711aa', 's1211', 'g118', 's1216', 's1233', 's1209', 's1228', 'g110', 'g122', 's524af', 's470b', 's1312a', 'gidx', 's1220', 's815e', 's1226', 'g102', 's1201', 'g124', 'g100', 'g117b', 's711g', 's1111', 'g107', 's413d', 'g115', 's711ae', 'g117d', 'g119', 's413f', 's1231', 's711c', 's711af', 's1210', 's1227', 's711ac', 's524ac', 'g117e', 'g104', 's1204', 's524ad', 's524ab', 's470a', 's524aa', 'g117y', 's524ax', 's1207', 's1218', 's524ag', 'g109', 's815g', 'g116', 's1223', 's109a', 's1221', 's1206', 's1205', 's1217', 'g112', 's1222', 's524ah', 'g106', 'g113', 'g117c', 'idx97', 'g117h', 's1219', 'g101', 'g117f', 's1229', 'g108', 'g105', 's711b', 's815f', 's1224'}
#     Additional columns (76): {'s1111b1', 's1303', 's1305b', 's412a', 'dpt4y', 's1111a1', 's1304c', 's1310fa', 'dpt4', 's1320', 's1107a', 's604a', 's1310cx', 's1318', 's1111b2', 's1111g1', 's1111a2', 's1305a', 's1304a', 'ipvy', 's1315', 's1310ca', 's1111g2', 's1310dy', 's1310ea', 's1310bx', 'dpt4d', 's1316', 's1311', 's1111e2', 's109', 's1304b', 's1111f1', 's1319', 's1310fy', 's1310ey', 's1111h2', 's1310ex', 's1111h1', 's1310aa', 's1310cb', 's1107c', 's1111d2', 'ipvd', 's1310cy', 's905', 's1111e1', 'ipvm', 's1308', 's1317', 's1310da', 's1111d1', 's1115', 's1310by', 's1107b', 's1310ab', 's1111c2', 's1301', 's1310fx', 'ipv', 's1309', 's1310bb', 's1313', 's1310dx', 's1310db', 's1312', 'dpt4m', 's1310ay', 's1310eb', 's1310ba', 's1310fb', 's1116', 's1314', 's1111c1', 's1111f2', 's1310ax'}
# BJ: Columns do not match
#     Similar columns (1094): {'v140', 'v474f', 'h21', 'm57a', 'h53d', 'v105', 'v525', 'hw56', 'ALT_GPS', 'v222', 'v469x', 'v028', 'v155', 'v413a', 'm65b', 'v411', 'v376', 'v745c', 'h8', 'v401', 'h12v', 'ml13y', 'hw12', 'ml14y', 'm57u', 'v104', 'v3a08f', 'v458', 'm2a', 'h36d', 's1213', 'v007', 'v507', 'v414i', 'v223', 'v472a', 'h58d', 'h50', 'h62d', 'm55f', 'v481g', 'm2d', 'hw53', 'v394', 'idx94', 'ml13g', 'v3a01', 'v045b', 'm57h', 'v414u', 'm65c', 'v743a', 'v3a00i', 'v404', 'v013', 'm45', 'ml13p', 'h12w', 'h45', 'h43', 'ml14z', 's1212', 'hw9', 's1215', 'h12f', 'v204', 'ml13l', 'ml21c', 'v014', 'h15j', 'v231', 'hw70', 'h53', 'v413', 's1211', 'ml15b', 'm57v', 'm1', 'm57m', 'v3a08d', 'm57p', 'm65i', 'm19', 'b9', 'h12t', 'bidx', 'v001', 'v602', 'm55l', 'v633c', 'h37aa', 'h36f', 'h37z', 's1209', 'ml13da', 'v017', 'v420', 'h6', 'h37c', 'awfacte', 'v153', 'm55m', 'm42d', 'v008', 'v474c', 'v440', 'v3a08ad', 'm8', 'ml16b', 'h13b', 'h62m', 'v731', 'v472h', 'h5', 'v476', 'h15g', 'h14', 'h10', 's815e', 'h63', 'h13', 'h11b', 'h57', 'v633g', 'v467c', 'v471e', 'm47', 'h66', 'v502', 'v310', 'ml25a', 'h56', 'b18', 'v471b', 'ml14a', 'm55d', 'ml13b', 'v501', 'v504', 'v168', 'v191a', 'm39a', 'v319', 'hw18', 'ml13e', 's413f', 'v131', 'v631', 'v510', 'v3a08r', 'v3a00y', 'v616', 'h80e', 'v032', 'h5m', 'v015', 'h37h', 'ml20c', 'v474x', 'v3a08q', 's1204', 'h31d', 'v364', 'b5', 'v137', 'm49a', 'h6d', 'v415', 'v107', 'm78b', 'v232', 'h32r', 'v3a00r', 's1218', 'v474', 'h63m', 'v325a', 'h9m', 's815g', 'h52y', 'h33', 'h15c', 'v216', 'DHSID', 'v414s', 'h37n', 'v045c', 'v129', 'h32m', 'm55e', 'v472q', 'v3a00d', 'h59m', 'v463h', 'h32h', 'v3a00q', 'h37p', 'ADM1FIPSNA', 'ml20b', 'h60', 'm78d', 'v235', 'v466', 'm15', 'm27', 'country', 'v3a00n', 'h21a', 'h12p', 'v3a08o', 'v633b', 'v411a', 'awfactr', 'ml13c', 's1217', 'v233', 'h55', 'ml19f', 'v474j', 'h6y', 'v511', 'h12y', 'v744a', 'v150', 'v471f', 'v315', 'v190', 'v3a08aa', 'v363', 'v472j', 'v535', 'm49g', 'h2y', 'v474i', 'v414j', 'h53y', 'v604', 'v134', 'b15', 'h32b', 'v508', 'v412b', 'v481c', 'm1a', 'v745b', 'v452a', 'h9', 'v472d', 'ADM1SALBCO', 'h37d', 'm36', 'v205', 'h15i', 'h50d', 'h32q', 'h37e', 'hidx', 'm70', 'v113', 'm49c', 'm44', 'v512', 'h7', 'm19a', 'v627', 'v418a', 'b3', 'ml22b', 'DHSYEAR', 'h9a', 'v416', 'v3a00t', 'v505', 'h32i', 'v214', 'v454', 'v3a00e', 'v021', 'h3m', 'm2i', 'h32u', 'h63d', 'v715', 'v102', 'v482b', 'v743b', 'v3a08l', 'v456', 'm1b', 'm72', 'v203', 'v237', 'v481f', 'm39', 'v3a04', 'h40y', 'v477', 'ml17a', 'b20', 'hw71', 'h5y', 'v019a', 'h37b', 'v138', 'm55h', 'v3a00v', 'v467a', 'h57m', 'v414l', 'm10', 'm57i', 'h37m', 'ml101', 'v472t', 'SOURCE', 'v215', 'm61', 'v012', 's1202', 'v3a08u', 'v224', 'v395', 'm65a', 'v474e', 'h37k', 'b1', 'v159', 'v414w', 'h50m', 'v413c', 'v3a00w', 'm2e', 'm3c', 'h2', 'h64y', 'h12s', 'v026', 'v3a09a', 'v414f', 'h58m', 'h38', 'm48', 'v481x', 'v509', 'v3a03', 'v3a00z', 'b13', 'b16', 'm55i', 'v023', 'v3a09b', 'ml13n', 'awfactu', 'v472b', 'h57d', 'v634', 'v407', 'v406', 'm55a', 'ml24c', 'v506', 'v530', 'h60y', 'm3d', 'v626', 'idxml', 'ADM1SALBNA', 'h41a', 'v130', 'v239', 'v3a08s', 'v480', 'h15h', 'h39', 'v008a', 'h60m', 'v379', 'v3a00b', 'v531', 'm64', 'h65y', 'h32n', 'h7y', 'v367', 'v459', 'v605', 'v463z', 'v457', 'ml18a', 'v745a', 'h58', 'v152', 'v141', 'b12', 'h66d', 'ADM1DHS', 'v228', 'm65d', 'v169a', 'h9ad', 'm78i', 'h54d', 'v125', 'v220', 'hw55', 'v359', 'v481a', 'h32v', 'v746', 'v120', 'v467k', 'm78g', 'v467j', 'h52m', 'v3a08m', 'v312', 'm2b', 'h60d', 'ml13m', 'v209', 'v472p', 'v453', 'h4m', 'v318', 'v414h', 'b8', 'ml0', 'b2', 'h2d', 'v115', 'm3m', 'm55z', 'b10', 'h32g', 'idx95', 'v743c', 'v240', 'v029', 'h15d', 'h62', 'ml13k', 'v414g', 'v025', 'v3a00c', 'h51m', 'v529', 'v3a08c', 'h12r', 'LONGNUM', 'm13', 'v437', 'ml13j', 'DHSREGCO', 'h55d', 'h55m', 'v474d', 'm2j', 'v464', 'hw17', 'h12m', 'v3a00j', 'v472n', 'v452b', 'h66y', 'ml22a', 'm66', 'v472l', 'v414n', 'v441', 'h32x', 'v463c', 'v539', 'v471d', 'v463b', 'v472m', 'h36c', 'h51', 'm55x', 'v704', 'h52', ' ...
#     Missing columns (84): {'g117j', 'g111', 's1232', 'g121', 'g117i', 's1203', 'g114', 'g117g', 's470c', 'sresid', 'g123', 's711ad', 'g103', 'g117x', 's1230', 's524ae', 's108', 'g117a', 's711ab', 's711aa', 'g118', 's1233', 's1228', 'g110', 'g122', 's524af', 's470b', 's1312a', 'gidx', 's1113', 's1226', 'g102', 's1201', 'g124', 'g100', 'g117b', 's711g', 's1111', 'g107', 's413d', 'g115', 's711ae', 'g117d', 'g119', 's1231', 's711c', 's711af', 's1210', 's1227', 's711ac', 's524ac', 'g117e', 'g104', 's524ad', 's524ab', 's470a', 's524aa', 'g117y', 's524ax', 's1207', 's524ag', 'g109', 'g116', 's1223', 's109a', 's1221', 's1206', 's1205', 'g112', 's1222', 's524ah', 'g106', 'g113', 'g117c', 'idx97', 'g117h', 's1112', 'g101', 'g117f', 's1229', 'g108', 'g105', 's711b', 's1224'}
#     Additional columns (113): {'s433a', 's815h', 's1210fy', 's106db', 's913a', 's1210cb', 's106dd', 's1206b', 's1412', 's1432d', 's1424', 's1432s', 's106c', 's1115s', 's1421', 's1210ex', 's1410', 's1417', 's816f', 's1405', 's1210cx', 's1406', 's124', 's1210ab', 's1210ba', 's413g', 's425b', 's631a', 's1401', 's816g', 's106fd', 's413h', 's1210ea', 's508yfd', 's1210aa', 's1407', 's1403', 's1210ax', 's1210db', 's508yfm', 's816i', 's1206a', 's1420', 'seduc', 's123ds', 's1402', 's106fs', 's123dd', 's423b', 's1439s', 's1411', 's423x', 's816a', 's423a', 's1210ay', 's1205b', 's1440s', 's1404', 's816h', 's1416', 's437a', 's1210da', 's1429', 's125', 's1210ey', 's1408', 's1427', 's1413', 's1433d', 's1210cy', 's1433s', 's1440d', 's1210ca', 's816b', 's1205a', 's1418', 's106da', 's1210by', 's1435s', 's816c', 's1409', 's1428', 's1419', 's1210bb', 's1210fa', 's1426', 's1423', 's1205c', 's1435d', 's1210dy', 's1210eb', 's1210fx', 's1210dx', 's908a', 's1422', 's106dc', 's816e', 's123c', 's816d', 's815i', 's1115d', 's1016a', 's508yfy', 's645a', 's1439d', 's1415', 's508yf', 's1421a', 's424b', 's1210fb', 's1210bx', 's425c', 's1414'}
# GA: Columns do not match
# ...
#     Missing columns (101): {'g117j', 'g111', 's1208', 's1213', 's1232', 'g121', 's1202', 'g117i', 's1203', 'g114', 'g117g', 's470c', 'sresid', 'g123', 's711ad', 'g103', 'g117x', 's1230', 's1212', 's524ae', 's1215', 'g117a', 's1214', 's711ab', 's711aa', 's1211', 'g118', 's1216', 's1233', 's1209', 's1228', 's904', 'g110', 'g122', 's524af', 's1312a', 'gidx', 's1220', 's815e', 's1113', 's1226', 'g102', 's1201', 'g124', 'g100', 'g117b', 's711g', 's1111', 'g107', 'g115', 's711ae', 'g117d', 'g119', 's413f', 's1231', 's711c', 's711af', 's1210', 's1227', 's711ac', 's524ac', 'g117e', 'g104', 's1204', 's524ad', 's524ab', 's470a', 's524aa', 'g117y', 's524ax', 's1207', 's1218', 's524ag', 'g109', 's815g', 'g116', 's1223', 's109a', 's1221', 's1206', 's1205', 's1217', 'g112', 's1222', 's524ah', 'g106', 'g113', 'g117c', 'idx97', 'g117h', 's1112', 's1219', 'g101', 'g117f', 's1114', 's1229', 'g108', 'g105', 's711b', 's815f', 's1224'}
#     Additional columns (158): {'ecd10g', 'mnv421', 'mnv444', 'sdv18b', 's1108il', 'mnv438', 'sdistrict', 's1108rn', 'ecd16', 's1110c', 's205cd', 's1110cbm', 'ecdage59', 'ecd10h', 'ecd6a', 'mnv445', 'mnv441', 'mnv452a', 's1108hd', 'ecd10i', 'ecdage24', 's413e', 's1110j', 's1010e', 's932f', 'mnv456', 's1108rk', 's1108rx', 's1108fd', 's610b', 's1108fc', 's525an', 'ecd10f', 's1108rm', 's205cc', 'ecd5a', 's657f', 's1108ri', 's1108hb', 'ecd10e', 's1108rl', 's660cc', 'ecd10b', 's656l', 's657d', 's1110cbd', 'mnv426', 's1010b', 's205cb', 'mnv453', 's412d', 's1010d', 's1108in', 's1108im', 'mnv458', 's1108rp', 'mnv420', 's205cz', 's1108fg', 's932k', 's660cd', 's1108g', 'ecd11', 's660ce', 'ecd10d', 's730a', 's1108fz', 's1108rj', 'ecd6b', 's1007a', 's1108ro', 'mnv439', 'ecd10c', 'mnv454', 'mnv457', 'mnv443', 's660ca', 'ecd10a', 's1110d', 's205ce', 's1108ff', 's720a3', 'mnv442', 's1108ha', 's1110f', 'mnv452b', 'ecd19', 's1108fa', 's653b', 's932i', 'mnv446', 'mnv447', 's1110i', 's205ca', 's1108hc', 's1108hz', 's109', 'mnv455', 's1110e', 'mnv447a', 'ecd20', 's657e', 's1110b', 's1110cad', 's1108fb', 's657a', 's412f', 'mnv440', 's1108ra', 's657c', 's1108q', 's1110cby', 's205cx', 'ecd4', 's1108rg', 'ecd2', 's1108rb', 's932j', 's660cb', 's1108io', 's1108ij', 's1110cay', 'mnv437', 's720a1', 's412b', 'ecd15', 'ecd5c', 's1108rf', 's660cf', 's1108fx', 's932g', 'mnv444a', 's457f', 'ecd12', 's1108rc', 'ecd14', 's1108rh', 's723a', 's1108fe', 'ecd5b', 'ecd13', 's1108re', 's1108hf', 'ecd8', 's1108rd', 's1108ik', 's1108he', 'mnv452c', 's657b', 's1108fh', 'ecd18', 'ecd17', 's653a', 's107', 's720a2', 'mnmicron', 'ecd9', 's1110cam'}
# LB: Columns do not match
#     Similar columns (1107): {'v140', 'v474f', 'h21', 'm57a', 'h53d', 'v105', 'v525', 'hw56', 'ALT_GPS', 'v222', 'v469x', 'v028', 'v155', 'v413a', 'm65b', 'v411', 'v376', 'v745c', 'h8', 'v401', 'h12v', 'ml13y', 'g117j', 'hw12', 'ml14y', 'm57u', 'v104', 'v3a08f', 'v458', 'm2a', 'h36d', 'g111', 'v007', 'v507', 'v414i', 'v223', 'v472a', 'h58d', 'h50', 'h62d', 'm55f', 'v481g', 'm2d', 'hw53', 'v394', 'idx94', 'ml13g', 'v3a01', 'v045b', 'g117i', 'm57h', 'g114', 'v414u', 'g117g', 'm65c', 'v743a', 'v3a00i', 'v404', 'v013', 'm45', 'ml13p', 'h12w', 'h45', 'h43', 'ml14z', 'hw9', 'h12f', 'v204', 'ml13l', 'ml21c', 'v014', 'h15j', 'v231', 'hw70', 'h53', 'v413', 'ml15b', 'm57v', 'm1', 'm57m', 'v3a08d', 'm57p', 'm65i', 'm19', 'b9', 'h12t', 'bidx', 'v001', 'v602', 'm55l', 'v633c', 'h37aa', 'h36f', 'h37z', 'ml13da', 'v017', 'v420', 'h6', 'h37c', 'awfacte', 'v153', 'm55m', 'm42d', 'v008', 'v474c', 'v440', 'v3a08ad', 'm8', 'ml16b', 'h13b', 'h62m', 'v731', 'v472h', 'h5', 'v476', 'h15g', 'h14', 'h10', 'g102', 'h63', 'h13', 'h11b', 'h57', 'v633g', 'v467c', 'v471e', 'm47', 'h66', 'v502', 'v310', 'ml25a', 'h56', 'b18', 'v471b', 'ml14a', 'm55d', 'ml13b', 'v501', 'v504', 'g115', 'v168', 'g119', 'v191a', 'm39a', 'v319', 'hw18', 'ml13e', 'v131', 'v631', 'v510', 'v3a08r', 'v3a00y', 'v616', 'h80e', 'v032', 'h5m', 'v015', 'h37h', 'ml20c', 'v474x', 'v3a08q', 'g104', 'h31d', 'v364', 'b5', 'v137', 'm49a', 'h6d', 'v415', 'v107', 'm78b', 'v232', 'h32r', 'v3a00r', 'v474', 'h63m', 'v325a', 'h9m', 'g109', 'h52y', 'h33', 'g116', 'h15c', 'v216', 'DHSID', 'v414s', 'h37n', 'v045c', 'v129', 'h32m', 'm55e', 'v472q', 'v3a00d', 'h59m', 'v463h', 'h32h', 'v3a00q', 'h37p', 'ADM1FIPSNA', 'ml20b', 'h60', 'm78d', 'v235', 'v466', 'm15', 'm27', 'country', 'v3a00n', 'h21a', 'h12p', 'v3a08o', 'v633b', 'v411a', 'awfactr', 'ml13c', 'v233', 'h55', 'ml19f', 'v474j', 'h6y', 'v511', 'h12y', 'v744a', 'v150', 'v471f', 'v315', 'v190', 'v3a08aa', 'v363', 'v472j', 'v535', 'm49g', 'h2y', 'v474i', 'v414j', 'h53y', 'v604', 'v134', 'b15', 'h32b', 'v508', 'v412b', 'v481c', 'm1a', 'v745b', 'v452a', 'h9', 'v472d', 'ADM1SALBCO', 'h37d', 'm36', 'v205', 'h15i', 'h50d', 'h32q', 'h37e', 'hidx', 'm70', 'v113', 'm49c', 'm44', 'v512', 'h7', 'm19a', 'v627', 'v418a', 'b3', 'ml22b', 'DHSYEAR', 'h9a', 'v416', 'v3a00t', 'v505', 'h32i', 'g108', 'v214', 'v454', 'v3a00e', 'v021', 'h3m', 'm2i', 'h32u', 'h63d', 'v715', 'v102', 'v482b', 'v743b', 'v3a08l', 'v456', 'm1b', 'm72', 'v203', 'v237', 'v481f', 'h40y', 'v3a04', 'm39', 'v477', 'ml17a', 'b20', 'hw71', 'h5y', 'v019a', 'h37b', 'v138', 'm55h', 'v3a00v', 'v467a', 'h57m', 'v414l', 'm10', 'm57i', 'h37m', 'ml101', 'v472t', 'SOURCE', 'v215', 'm61', 'v012', 'v3a08u', 'v224', 'v395', 'm65a', 'v474e', 'h37k', 'b1', 'v159', 'v414w', 'h50m', 'v413c', 'v3a00w', 'g103', 'g117x', 'm2e', 'm3c', 'h2', 'h64y', 'h12s', 'v026', 'v3a09a', 'v414f', 'h58m', 'h38', 'm48', 'v481x', 'v509', 'v3a03', 'v3a00z', 'b13', 'b16', 'm55i', 'v023', 'v3a09b', 'ml13n', 'awfactu', 'v472b', 'h57d', 'v634', 'v407', 'v406', 'm55a', 'ml24c', 'v506', 'v530', 'h60y', 'm3d', 'v626', 'idxml', 'ADM1SALBNA', 'h41a', 'v130', 'v239', 'v3a08s', 'v480', 'h15h', 'h39', 'v008a', 'g110', 'h60m', 'v379', 'v3a00b', 'v531', 'm64', 'h65y', 'h32n', 'h7y', 'v367', 'v459', 'v605', 'v463z', 'v457', 'ml18a', 'v745a', 'h58', 'v152', 'v141', 'b12', 'h66d', 'ADM1DHS', 'v228', 'm65d', 'v169a', 'h9ad', 'm78i', 'h54d', 'v125', 'v220', 'hw55', 'v359', 'v481a', 'h32v', 'v746', 'v120', 'v467k', 'm78g', 'v467j', 'h52m', 'v3a08m', 'v312', 'm2b', 'h60d', 'ml13m', 'g117b', 'v209', 'v472p', 'v453', 'h4m', 'v318', 'v414h', 'b8', 'ml0', 'b2', 'h2d', 'v115', 'm3m', 'm55z', 'b10', 'h32g', 'idx95', 'v743c', 'v240', 'v029', 'h15d', 'h62', 'ml13k', 'v414g', 'v025', 'v3a00c', 'h51m', 'v529', 'v3a08c', 'h12r', 'LONGNUM', 'm13', 'v437', 'ml13j', 'DHSREGCO', 'h55d', 'g117y', 'h55m', 'v474d', 'm2j', 'v464', 'hw17', 'h12m', 'v3a00j', 'v472n', 'v452b', 'h66y', 'ml22a', 'm66', 'v472l', 'v414n', 'v441', 'h32x', 'v463c', 'v539', 'v471d', 'v463b', 'v472m', 'h36c ...
#     Missing columns (71): {'s1214', 's711ab', 's711aa', 's711g', 's1221', 's1211', 's1111', 's413d', 's1216', 's711ae', 's1233', 's1206', 's413f', 's1231', 's1208', 's1213', 's1232', 's1205', 's1217', 's711c', 's711af', 's1209', 's1210', 's1227', 'g121', 's1222', 's1228', 's711ac', 's524ac', 's524ah', 'g122', 's524af', 's524ad', 's1204', 's1312a', 's470b', 's524ab', 'gidx', 's1202', 's470a', 's524aa', 's1203', 'idx97', 's524ax', 's470c', 's1207', 's1112', 's1219', 'sresid', 'g123', 's711ad', 's1220', 's1218', 's815e', 's1113', 's1226', 's524ag', 's815g', 's1212', 's1230', 's524ae', 's1114', 's1229', 's1201', 'g124', 's1215', 's1223', 's109a', 's711b', 's815f', 's1224'}
#     Additional columns (133): {'s1401c', 's1407d', 's434afc', 's1107ba', 's1110bct', 's1107a', 's1317a', 's1412', 's1401f', 'speduc', 'sd508yf1', 's1401i', 's1107bb', 's1407n', 's1401e', 's1407m', 's1421', 's1110ba', 's1410', 's1417', 's1317c', 's1528b', 's1425b', 's1405', 'srestype', 's1107be', 's1406', 's1401a', 'seducat', 's1407c', 's508yf1', 's1425a', 's1403y', 's1416a', 's1424d', 's434afd', 's1110a', 's434afe', 's1407b', 's434afa', 's1407e', 's1107bg', 's413abb', 's1407q', 's1401n', 's1407f', 's1424b', 's1419y', 's434ab', 's1425d', 's1401g', 's1407j', 's1528a', 's1401o', 's1407i', 's1425e', 's1420', 's1425c', 's1402', 's1424a', 's1424c', 's1424x', 's434ac', 's1416b', 's1401k', 's413abf', 's1407l', 's1401h', 's1411', 's1424f', 's524a', 's1401j', 's1407g', 's104', 's1403m', 's1416c', 's1404', 's413abg', 's1401z', 'sm508yf1', 's1408', 's413aba', 's1413', 's1401l', 's1407x', 's109', 's1419m', 'sreduc', 's1418', 's1407o', 's1107bc', 's1407p', 's1407k', 's1409y', 's413abx', 's1423', 's1107bf', 's1110bb', 's434afb', 's123', 's1110bat', 's1422', 's434ad', 's1401d', 's413abe', 's413abh', 's1527', 's1107bd', 's1110bc', 'scountyc', 's1401b', 's1401m', 's1017a', 's1407a', 's434afx', 's1107bz', 's1409m', 's1424e', 's1424g', 's1107bx', 's905', 'sy508yf1', 's1415', 's1110bbt', 's1421a', 's413abc', 's903', 's1317b', 's107', 's413abd', 's1407h', 's434ae', 's1414'}
# ZM: Columns do not match
#     Similar columns (1084): {'v140', 'v474f', 'h21', 'm57a', 'h53d', 'v105', 'v525', 'hw56', 'ALT_GPS', 'v222', 'v469x', 'v028', 'v155', 'v413a', 'm65b', 'v411', 'v376', 'v745c', 'h8', 'v401', 'h12v', 'ml13y', 'hw12', 'ml14y', 'm57u', 'v104', 'v3a08f', 'v458', 'm2a', 'h36d', 'v007', 'v507', 'v414i', 'v223', 'v472a', 'h58d', 'h50', 'h62d', 'm55f', 'v481g', 'm2d', 'hw53', 'v394', 'idx94', 'ml13g', 'v3a01', 'v045b', 'm57h', 'v414u', 'm65c', 'v743a', 'v3a00i', 'v404', 'v013', 'm45', 'ml13p', 'h12w', 'h45', 'h43', 'ml14z', 'hw9', 'h12f', 'v204', 'ml13l', 'ml21c', 'v014', 'h15j', 'v231', 'hw70', 'h53', 'v413', 's1211', 'ml15b', 'm57v', 'm1', 'm57m', 'v3a08d', 'm57p', 'm65i', 'm19', 'b9', 'h12t', 'bidx', 'v001', 'v602', 'm55l', 'v633c', 'h37aa', 'h36f', 'h37z', 's1209', 'ml13da', 'v017', 'v420', 'h6', 'h37c', 'awfacte', 'v153', 'm55m', 'm42d', 'v008', 'v474c', 'v440', 'v3a08ad', 'm8', 'ml16b', 'h13b', 'h62m', 'v731', 'v472h', 'h5', 'v476', 'h15g', 'h14', 'h10', 'h63', 'h13', 'h11b', 'h57', 'v633g', 'v467c', 'v471e', 'm47', 'h66', 'v502', 'v310', 'ml25a', 'h56', 'b18', 'v471b', 'ml14a', 'm55d', 'ml13b', 'v501', 'v504', 'v168', 'v191a', 'm39a', 'v319', 'hw18', 'ml13e', 'v131', 'v631', 'v510', 'v3a08r', 'v3a00y', 'v616', 's1210', 'h80e', 'v032', 'h5m', 'v015', 'h37h', 'ml20c', 'v474x', 'v3a08q', 's1204', 'h31d', 'v364', 'b5', 'v137', 'm49a', 'h6d', 'v415', 'v107', 'm78b', 'v232', 'h32r', 'v3a00r', 'v474', 'h63m', 'v325a', 'h9m', 'h52y', 'h33', 'h15c', 'v216', 'DHSID', 'v414s', 'h37n', 'v045c', 'v129', 'h32m', 'm55e', 'v472q', 'v3a00d', 'h59m', 'v463h', 'h32h', 'v3a00q', 'h37p', 'ADM1FIPSNA', 'ml20b', 'h60', 'm78d', 'v235', 'v466', 'm15', 'm27', 'country', 'v3a00n', 'h21a', 'h12p', 'v3a08o', 'v633b', 'v411a', 'awfactr', 'ml13c', 'v233', 'h55', 'ml19f', 'v474j', 'h6y', 'v511', 'h12y', 'v744a', 'v150', 'v471f', 'v315', 'v190', 'v3a08aa', 'v363', 'v472j', 'v535', 'm49g', 'h2y', 'v474i', 'v414j', 'h53y', 'v604', 'v134', 'b15', 'h32b', 'v508', 'v412b', 'v481c', 'm1a', 'v745b', 'v452a', 'h9', 'v472d', 'ADM1SALBCO', 'h37d', 'm36', 'v205', 'h15i', 'h50d', 'h32q', 'h37e', 'hidx', 'm70', 'v113', 'm49c', 'm44', 'v512', 'h7', 'm19a', 'v627', 'v418a', 'b3', 'ml22b', 'DHSYEAR', 'h9a', 'v416', 'v3a00t', 'v505', 'h32i', 'v214', 'v454', 'v3a00e', 'v021', 'h3m', 'm2i', 'h32u', 'h63d', 'v715', 'v102', 'v482b', 'v743b', 'v3a08l', 'v456', 'm1b', 'm72', 'v203', 'v237', 'v481f', 'm39', 'v3a04', 'h40y', 'v477', 'ml17a', 'b20', 'hw71', 'h5y', 'v019a', 'h37b', 'v138', 'm55h', 'v3a00v', 'v467a', 'h57m', 'v414l', 'm10', 'm57i', 'h37m', 'ml101', 'v472t', 'SOURCE', 'v215', 'm61', 'v012', 's1202', 'v3a08u', 'v224', 'v395', 'm65a', 'v474e', 'h37k', 's1203', 'b1', 'v159', 'v414w', 'h50m', 'v413c', 'v3a00w', 'm2e', 'm3c', 'h2', 'h64y', 'h12s', 'v026', 'v3a09a', 'v414f', 'h58m', 'h38', 'm48', 'v481x', 'v509', 'v3a03', 'v3a00z', 'b13', 'b16', 'm55i', 'v023', 'v3a09b', 'ml13n', 'awfactu', 'v472b', 'h57d', 'v634', 'v407', 'v406', 'm55a', 'ml24c', 'v506', 'v530', 'h60y', 'm3d', 'v626', 'idxml', 'ADM1SALBNA', 'h41a', 'v130', 'v239', 'v3a08s', 'v480', 'h15h', 'h39', 'v008a', 'h60m', 'v379', 'v3a00b', 'v531', 'm64', 'h65y', 'h32n', 'h7y', 'v367', 'v459', 'v605', 'v463z', 'v457', 'ml18a', 'v745a', 'h58', 'v152', 'v141', 'b12', 'h66d', 'ADM1DHS', 'v228', 'm65d', 'v169a', 'h9ad', 'm78i', 'h54d', 'v125', 'v220', 's1201', 'hw55', 'v359', 'v481a', 'h32v', 'v746', 'v120', 'v467k', 'm78g', 'v467j', 'h52m', 'v3a08m', 'v312', 'm2b', 'h60d', 'ml13m', 'v209', 'v472p', 'v453', 'h4m', 'v318', 'v414h', 'b8', 'ml0', 'b2', 'h2d', 'v115', 'm3m', 'm55z', 'b10', 'h32g', 'idx95', 'v743c', 'v240', 'v029', 'h15d', 'h62', 'ml13k', 'v414g', 'v025', 'v3a00c', 'h51m', 'v529', 'v3a08c', 'h12r', 'LONGNUM', 'm13', 'v437', 'ml13j', 'DHSREGCO', 'h55d', 'h55m', 'v474d', 'm2j', 'v464', 'hw17', 's1207', 'h12m', 'v3a00j', 'v472n', 'v452b', 'h66y', 'ml22a', 'm66', 'v472l', 'v414n', 'v441', 'h32x', 'v463c', 'v539', 'v471d', 'v463b', 'v472m', 'h36c', 'h51', 'm55x', 'v704', 'h52', 'v384b', 'v3a08t', 'v322', 'h33d', 'c ...
#     Missing columns (94): {'g117j', 'g111', 's1208', 's1213', 's1232', 'g121', 'g117i', 'g114', 'g117g', 's470c', 'sresid', 'g123', 's711ad', 'g103', 'g117x', 's1230', 's1212', 's524ae', 's1215', 's108', 'g117a', 's1214', 's711ab', 's711aa', 'g118', 's1216', 's1233', 's1228', 's904', 'g110', 'g122', 's524af', 's470b', 's1312a', 'gidx', 's1220', 's815e', 's1113', 's1226', 'g102', 'g124', 'g100', 'g117b', 's711g', 's1111', 'g107', 's413d', 'g115', 's711ae', 'g117d', 'g119', 's413f', 's1231', 's711c', 's711af', 's1227', 's711ac', 's524ac', 'g117e', 'g104', 's524ad', 's524ab', 's470a', 's524aa', 'g117y', 's524ax', 's1218', 's524ag', 'g109', 's815g', 'g116', 's1223', 's109a', 's1221', 's1217', 'g112', 's1222', 's524ah', 'g106', 'g113', 'g117c', 'idx97', 'g117h', 's1112', 's1219', 'g101', 'g117f', 's1114', 's1229', 'g108', 'g105', 's711b', 's815f', 's1224'}
#     Additional columns (70): {'s1111db', 's1019ae', 's1208f', 's1208a', 's1111bk', 's1208g', 's1111dh', 's1029ad', 's1208d', 's908a', 's614a', 's816ab', 's1111bg', 's1111dc', 's1111di', 's1110d', 's1111df', 's1111bo', 's1111bb', 's1110c', 's1111de', 'shp4y', 's1111dd', 's1029ac', 's1111bh', 's1208c', 's1208x', 's1111bl', 's1111bm', 's816b', 's1111bd', 's1023ab', 's1111bx', 's1019ad', 's1208b', 's1111dg', 's1110b', 's1023ad', 's1029ab', 'shp4', 's1111ba', 's1050a', 's1019ab', 's1208h', 's816aa', 's1111dx', 's932f', 's1029ae', 's1111bc', 's1111bn', 's1111da', 's1111dj', 's1029aa', 's1019aa', 's1208e', 's1111a', 's1111bi', 's1111bj', 's1111cc', 's1111c', 'shp4d', 's1110a', 'shp4m', 's1023ac', 's1023ae', 's1111be', 's1023aa', 's1019ac', 's1111bf', 's816a'}

# %%
# concatenate countries' datasets - dropping all unsimilar columns
BRGE_concat = pd.concat(BRGE_data.values(), join='inner', ignore_index=True)
print(list(BRGE_concat.columns))
print(f"Number of columns: {len(BRGE_concat.columns)}")
# Out:
# ['caseid', 'bidx', 'v000', 'v001', 'v002', 'v003', 'v004', 'v005', 'v006', 'v007', 'v008', 'v009', 'v010', 'v011', 'v012', 'v013', 'v014', 'v015', 'v016', 'v017', 'v018', 'v019', 'v019a', 'v020', 'v021', 'v022', 'v023', 'v024', 'v025', 'v026', 'v027', 'v028', 'v029', 'v030', 'v031', 'v032', 'v034', 'v040', 'v042', 'v044', 'v101', 'v102', 'v103', 'v104', 'v105', 'v106', 'v107', 'v113', 'v115', 'v116', 'v119', 'v120', 'v121', 'v122', 'v123', 'v124', 'v125', 'v127', 'v128', 'v129', 'v130', 'v131', 'v133', 'v134', 'v135', 'v136', 'v137', 'v138', 'v139', 'v140', 'v141', 'v149', 'v150', 'v151', 'v152', 'v153', 'awfactt', 'awfactu', 'awfactr', 'awfacte', 'awfactw', 'v155', 'v156', 'v157', 'v158', 'v159', 'v160', 'v161', 'v166', 'v167', 'v168', 'v190', 'v191', 'ml101', 'v201', 'v202', 'v203', 'v204', 'v205', 'v206', 'v207', 'v208', 'v209', 'v210', 'v211', 'v212', 'v213', 'v214', 'v215', 'v216', 'v217', 'v218', 'v219', 'v220', 'v221', 'v222', 'v223', 'v224', 'v225', 'v226', 'v227', 'v228', 'v229', 'v230', 'v231', 'v232', 'v233', 'v234', 'v235', 'v237', 'v238', 'v239', 'v240', 'v241', 'v242', 'v243', 'v310', 'v311', 'v312', 'v313', 'v315', 'v316', 'v317', 'v318', 'v319', 'v320', 'v321', 'v322', 'v323', 'v323a', 'v325a', 'v326', 'v327', 'v337', 'v359', 'v360', 'v361', 'v362', 'v363', 'v364', 'v367', 'v372', 'v372a', 'v375a', 'v376', 'v376a', 'v379', 'v380', 'v384a', 'v384b', 'v384c', 'v393', 'v394', 'v395', 'v3a00a', 'v3a00b', 'v3a00c', 'v3a00d', 'v3a00e', 'v3a00f', 'v3a00g', 'v3a00h', 'v3a00i', 'v3a00j', 'v3a00k', 'v3a00l', 'v3a00m', 'v3a00n', 'v3a00o', 'v3a00p', 'v3a00q', 'v3a00r', 'v3a00s', 'v3a00t', 'v3a00u', 'v3a00v', 'v3a00w', 'v3a00x', 'v3a00y', 'v3a00z', 'v3a01', 'v3a02', 'v3a03', 'v3a04', 'v3a05', 'v3a06', 'v3a07', 'v3a08a', 'v3a08b', 'v3a08c', 'v3a08d', 'v3a08e', 'v3a08f', 'v3a08g', 'v3a08h', 'v3a08i', 'v3a08j', 'v3a08k', 'v3a08l', 'v3a08m', 'v3a08n', 'v3a08o', 'v3a08p', 'v3a08q', 'v3a08r', 'v3a08s', 'v3a08t', 'v3a08u', 'v3a08v', 'v3a08w', 'v3a08aa', 'v3a08ab', 'v3a08ac', 'v3a08ad', 'v3a08x', 'v3a08z', 'v3a09a', 'v3a09b', 'v401', 'v404', 'v405', 'v406', 'v407', 'v408', 'v409', 'v409a', 'v410', 'v410a', 'v411', 'v411a', 'v412', 'v412a', 'v412b', 'v412c', 'v413', 'v413a', 'v413b', 'v413c', 'v413d', 'v414a', 'v414b', 'v414c', 'v414d', 'v414e', 'v414f', 'v414g', 'v414h', 'v414i', 'v414j', 'v414k', 'v414l', 'v414m', 'v414n', 'v414o', 'v414p', 'v414q', 'v414r', 'v414s', 'v414t', 'v414u', 'v414v', 'v414w', 'v415', 'v416', 'v417', 'v418', 'v419', 'v420', 'v421', 'v426', 'v437', 'v438', 'v445', 'v447', 'v447a', 'v452a', 'v452b', 'v452c', 'v453', 'v454', 'v455', 'v456', 'v457', 'v458', 'v459', 'v460', 'v461', 'v462', 'v463a', 'v463b', 'v463c', 'v463d', 'v463e', 'v463f', 'v463g', 'v463x', 'v463z', 'v464', 'v465', 'v466', 'v467a', 'v467b', 'v467c', 'v467d', 'v467e', 'v467f', 'v467g', 'v467h', 'v467i', 'v467j', 'v467k', 'v467l', 'v467m', 'v468', 'v469e', 'v469f', 'v469x', 'v471a', 'v471b', 'v471c', 'v471d', 'v471e', 'v471f', 'v471g', 'v472a', 'v472b', 'v472c', 'v472d', 'v472e', 'v472f', 'v472g', 'v472h', 'v472i', 'v472j', 'v472k', 'v472l', 'v472m', 'v472n', 'v472o', 'v472p', 'v472q', 'v472r', 'v472s', 'v472t', 'v472u', 'v473a', 'v473b', 'v477', 'v478', 'v479', 'v480', 'v481', 'v481a', 'v481b', 'v481c', 'v481d', 'v481e', 'v481f', 'v481g', 'v481h', 'v481x', 'v482a', 'v482b', 'v482c', 'v501', 'v502', 'v503', 'v504', 'v505', 'v506', 'v507', 'v508', 'v509', 'v510', 'v511', 'v512', 'v513', 'v525', 'v527', 'v528', 'v529', 'v530', 'v531', 'v532', 'v535', 'v536', 'v537', 'v538', 'v539', 'v540', 'v541', 'v602', 'v603', 'v604', 'v605', 'v613', 'v614', 'v616', 'v621', 'v623', 'v624', 'v625', 'v626', 'v625a', 'v626a', 'v627', 'v628', 'v629', 'v631', 'v632', 'v633a', 'v633b', 'v633c', 'v633d', 'v633e', 'v633f', 'v633g', 'v634', 'v701', 'v702', 'v704', 'v705', 'v714', 'v714a', 'v715', 'v716', 'v717', 'v719', 'v721', 'v729', 'v730', 'v731', 'v732', 'v739', 'v740', 'v741', 'v743a', 'v743b', 'v743c', 'v743d', 'v743e', 'v743f', 'v744a', 'v744b', 'v744c', 'v74 ...
# Number of columns: 794

# %%
# Drop columns that are completely NaN
columns_before = BRGE_concat.shape[1]
BRGE_concat = BRGE_concat.dropna(axis='columns', how='all')
columns_after = BRGE_concat.shape[1]
columns_dropped = columns_before - columns_after
print(f"Number of columns dropped: {columns_dropped}")  
print(f"Number of columns left: {columns_after}")
# Out:
# Number of columns dropped: 71
# Number of columns left: 723

# %%
# removing observations that have missing for the midx - children not born within the past 5 years
def drop_rows_with_na_in_midx(df):
    rows_before = len(df)
    modified_df = df.dropna(subset=['midx'])
    rows_after = len(modified_df)
    
    rows_dropped = rows_before - rows_after
    if rows_dropped > 0:
        print(f"Dropped {rows_dropped} rows where 'midx' was NaN.")
        print(f"Left with {rows_after} rows representing children born in the past 5 years.")
    else:
        print("No rows were dropped as 'midx' had no NaN values.")
    
    return modified_df

BRGE_concat_modified = drop_rows_with_na_in_midx(BRGE_concat)
# Out:
# Dropped 974386 rows where 'midx' was NaN.
# Left with 324841 rows representing children born in the past 5 years.

# %%
# pickling the BRGE_modified file
f = open('Processed_Datasets/BR_processing.pkl', 'wb')
pickle.dump(BRGE_concat_modified, f)

# %%
# pickling the metadata file
f = open('Processed_Datasets/BR_processing_metadata.pkl', 'wb')
pickle.dump(BR_metadata, f)
f.close()
