# %%
import pandas as pd
import numpy as np
import pickle
from sklearn import preprocessing
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.cluster import AgglomerativeClustering
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import silhouette_score
from tqdm import tqdm
from statistics import mean

# %%
CD_data = pickle.load(open('Processed_Datasets/CD_prepared.pkl', 'rb'))

# %%
df_train = CD_data.drop(['Cluster\'s latitude coordinate', 'Cluster\'s longitude coordinate'], axis=1)
df_train = df_train.reset_index(drop=True)

# %%
feature_list = ['PreceedingBirthInterval(33+)', 'WasBreastfed', 'HealthFacilityDelivery', 'SkilledDeliveryCareProvider', 
            'AntenatalCare(4+)', 'NeonatalTetanusProtection(2+)', 'IronPillsDuringPregnancy',
            'BabyPostnatalCheck', 'MaternalPostpartumHealthCheck', 'MetNeedFamilyPlanning',
            'CleanCookingFuel', 'ProtectedDrinkingWaterSource', 'ImprovedToiletFacility', 
            'NonTobaccoSmoker', 'DecisionMaking_Participation', 
            'OfAgeMarriage']

selected_features = df_train[feature_list]
zero_rows = selected_features.sum(axis=1) == 0

df_train = df_train[~zero_rows]
df_train = df_train.reset_index(drop=True)

# %%
X_train = df_train[['PreceedingBirthInterval(33+)', 'WasBreastfed', 'HealthFacilityDelivery', 'SkilledDeliveryCareProvider', 
            'AntenatalCare(4+)', 'NeonatalTetanusProtection(2+)', 'IronPillsDuringPregnancy',
            'BabyPostnatalCheck', 'MaternalPostpartumHealthCheck', 'MetNeedFamilyPlanning',
            'CleanCookingFuel', 'ProtectedDrinkingWaterSource', 'ImprovedToiletFacility', 
            'NonTobaccoSmoker', 'DecisionMaking_Participation', 
            'OfAgeMarriage']]
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9307 entries, 0 to 9306
# Data columns (total 16 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   PreceedingBirthInterval(33+)   9307 non-null   object
#  1   WasBreastfed                   9307 non-null   object
#  2   HealthFacilityDelivery         9307 non-null   object
#  3   SkilledDeliveryCareProvider    9307 non-null   object
#  4   AntenatalCare(4+)              9307 non-null   object
#  5   NeonatalTetanusProtection(2+)  9307 non-null   object
#  6   IronPillsDuringPregnancy       9307 non-null   object
#  7   BabyPostnatalCheck             9307 non-null   object
#  8   MaternalPostpartumHealthCheck  9307 non-null   object
#  9   MetNeedFamilyPlanning          9307 non-null   object
#  10  CleanCookingFuel               9307 non-null   object
#  11  ProtectedDrinkingWaterSource   9307 non-null   object
#  12  ImprovedToiletFacility         9307 non-null   object
#  13  NonTobaccoSmoker               9307 non-null   object
#  14  DecisionMaking_Participation   9307 non-null   object
#  15  OfAgeMarriage                  9307 non-null   object
# dtypes: object(16)
# memory usage: 1.1+ MB

# %%
encoder = OneHotEncoder(drop='first', sparse_output=False)

X_train_encoded = pd.DataFrame(encoder.fit_transform(X_train), columns = encoder.get_feature_names_out(X_train.columns))
X_train_encoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9307 entries, 0 to 9306
# Data columns (total 18 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   PreceedingBirthInterval(33+)_1   9307 non-null   float64
#  1   PreceedingBirthInterval(33+)_2   9307 non-null   float64
#  2   WasBreastfed_1                   9307 non-null   float64
#  3   HealthFacilityDelivery_1         9307 non-null   float64
#  4   SkilledDeliveryCareProvider_1    9307 non-null   float64
#  5   AntenatalCare(4+)_1              9307 non-null   float64
#  6   NeonatalTetanusProtection(2+)_1  9307 non-null   float64
#  7   IronPillsDuringPregnancy_1       9307 non-null   float64
#  8   BabyPostnatalCheck_1             9307 non-null   float64
#  9   MaternalPostpartumHealthCheck_1  9307 non-null   float64
#  10  MetNeedFamilyPlanning_1          9307 non-null   float64
#  11  MetNeedFamilyPlanning_2          9307 non-null   float64
#  12  CleanCookingFuel_1               9307 non-null   float64
#  13  ProtectedDrinkingWaterSource_1   9307 non-null   float64
#  14  ImprovedToiletFacility_1         9307 non-null   float64
#  15  NonTobaccoSmoker_1               9307 non-null   float64
#  16  DecisionMaking_Participation_1   9307 non-null   float64
#  17  OfAgeMarriage_1                  9307 non-null   float64
# dtypes: float64(18)
# memory usage: 1.3 MB

# %% [markdown]
# ### Dimensionality reduction using MCA

# %%
import prince
def hyperparameter_tuning(X_train, n_components_range, n_clusters_range):
    variance_explained = {}
    kmeans_silhouette_scores = {}
    hierarchical_silhouette_scores = {}

    nominal_data = X_train
    nominal_data_encoded = OneHotEncoder(drop='first', sparse_output=False).fit_transform(nominal_data)

    for n_components in tqdm(n_components_range, desc='Evaluating n_components'):

        mca = prince.MCA(n_components=n_components, random_state=42).fit(nominal_data)
        
        ### Obtain variance explained values
        variance_explained[n_components] = mca.eigenvalues_summary['% of variance (cumulative)'].iloc[-1]
        
        nominal_fit_data = mca.transform(nominal_data)
        
        ### Apply Hierarchical and evaluate silhouette score for different values of k
        h_silhouette_scores = {}
        for k in tqdm(n_clusters_range, desc='Looping through values of k', leave=False):
            untrained_model = AgglomerativeClustering(n_clusters=k, 
                                                      metric = 'euclidean', 
                                                      linkage='average', 
                                                       distance_threshold=None)
            trained_model = untrained_model.fit(nominal_fit_data)
            cluster_labels = trained_model.labels_
            score = silhouette_score(nominal_fit_data, cluster_labels)
            h_silhouette_scores[k] = score

        hierarchical_silhouette_scores[n_components] = h_silhouette_scores

        ### Apply K-Means and evaluate silhouette score for different values of k
        k_silhouette_scores = {}
        for k in tqdm(n_clusters_range, desc='Looping through values of k', leave=False):
            untrained_model = KMeans(n_clusters=k, n_init=10, init = 'k-means++', random_state=42)
            trained_model = untrained_model.fit(nominal_fit_data)
            cluster_labels = trained_model.labels_
            score = silhouette_score(nominal_fit_data, cluster_labels)
            k_silhouette_scores[k] = score

        kmeans_silhouette_scores[n_components] = k_silhouette_scores

    return variance_explained, kmeans_silhouette_scores, hierarchical_silhouette_scores

# %%
n_components_range = range(2, 17)
n_clusters_range = range(2, 9)
variance_explained, kmeans_silhouette_scores, hierarchical_silhouette_scores = hyperparameter_tuning(X_train, 
                                                                                                     n_components_range,
                                                                                                     n_clusters_range)
# Out:
# Evaluating n_components:   0%|                                                      | 0/15 [00:00<?, ?it/s]
# Looping through values of k:   0%|                                                   | 0/7 [00:00<?, ?it/s]
# Looping through values of k:  14%|██████▏                                    | 1/7 [00:01<00:10,  1.72s/it]
# Looping through values of k:  29%|████████████▎                              | 2/7 [00:03<00:08,  1.64s/it]
# Looping through values of k:  43%|██████████████████▍                        | 3/7 [00:04<00:06,  1.58s/it]
# Looping through values of k:  57%|████████████████████████▌                  | 4/7 [00:06<00:04,  1.57s/it]
# Looping through values of k:  71%|██████████████████████████████▋            | 5/7 [00:07<00:03,  1.55s/it]
# Looping through values of k:  86%|████████████████████████████████████▊      | 6/7 [00:09<00:01,  1.52s/it]
# Looping through values of k: 100%|███████████████████████████████████████████| 7/7 [00:10<00:00,  1.51s/it]
#
# Looping through values of k:   0%|                                                   | 0/7 [00:00<?, ?it/s]
# Looping through values of k:  14%|██████▏                                    | 1/7 [00:03<00:20,  3.35s/it]
# Looping through values of k:  29%|████████████▎                              | 2/7 [00:06<00:16,  3.22s/it]
# Looping through values of k:  43%|██████████████████▍                        | 3/7 [00:09<00:12,  3.07s/it]
# Looping through values of k:  57%|████████████████████████▌                  | 4/7 [00:11<00:08,  2.83s/it]
# Looping through values of k:  71%|██████████████████████████████▋            | 5/7 [00:15<00:06,  3.02s/it]
# Looping through values of k:  86%|████████████████████████████████████▊      | 6/7 [00:18<00:03,  3.05s/it]
# Looping through values of k: 100%|███████████████████████████████████████████| 7/7 [00:21<00:00,  3.05s/it]
# Evaluating n_components:   7%|███                                           | 1/15 [00:35<08:19, 35.66s/it]
# Looping through values of k:   0%|                                                   | 0/7 [00:00<?, ?it/s]
# Looping through values of k:  14%|██████▏                                    | 1/7 [00:01<00:10,  1.78s/it]
# Looping through values of k:  29%|████████████▎                              | 2/7 [00:03<00:08,  1.80s/it]
# Looping through values of k:  43%|██████████████████▍                        | 3/7 [00:05<00:07,  1.77s/it]
# Looping through values of k:  57%|████████████████████████▌                  | 4/7 [00:07<00:05,  1.76s/it]
# Looping through values of k:  71%|██████████████████████████████▋            | 5/7 [00:08<00:03,  1.75s/it]
# Looping through values of k:  86%|████████████████████████████████████▊      | 6/7 [00:10<00:01,  1.73s/it]
# Looping through values of k: 100%|███████████████████████████████████████████| 7/7 [00:12<00:00,  1.72s/it]
#
# Looping through values of k:   0%|                                                   | 0/7 [00:00<?, ?it/s]
# Looping through values of k:  14%|██████▏                                    | 1/7 [00:03<00:20,  3.41s/it]
# Looping through values of k:  29%|████████████▎                              | 2/7 [00:06<00:16,  3.27s/it]
# Looping through values of k:  43%|██████████████████▍                        | 3/7 [00:09<00:13,  3.29s/it]
# Looping through values of k:  57%|████████████████████████▌                  | 4/7 [00:13<00:09,  3.33s/it]
# Looping through values of k:  71%|██████████████████████████████▋            | 5/7 [00:14<00:05,  2.69s/it]
# Looping through values of k:  86%|████████████████████████████████████▊      | 6/7 [00:17<00:02,  2.75s/it]
# Looping through values of k: 100%|███████████████████████████████████████████| 7/7 [00:18<00:00,  2.16s/it]
# Evaluating n_components:  13%|██████▏                                       | 2/15 [01:10<07:33, 34.91s/it]
# Looping through values of k:   0%|                                                   | 0/7 [00:00<?, ?it/s]
# Looping through values of k:  14%|██████▏                                    | 1/7 [00:01<00:10,  1.69s/it]
# Looping through values of k:  29%|████████████▎                              | 2/7 [00:03<00:08,  1.70s/it]
# Looping through values of k:  43%|██████████████████▍                        | 3/7 [00:05<00:06,  1.72s/it]
# Looping through values of k:  57%|████████████████████████▌                  | 4/7 [00:06<00:04,  1.66s/it]
# Looping through values of k:  71%|██████████████████████████████▋            | 5/7 [00:08<00:03,  1.63s/it]
# Looping through values of k:  86%|████████████████████████████████████▊      | 6/7 [00:09<00:01,  1.58s/it]
# Looping through values of k: 100%|███████████████████████████████████████████| 7/7 [00:11<00:00,  1.57s/it]
#
# Looping through values of k:   0%|                                                   | 0/7 [00:00<?, ?it/s]
# Looping through values of k:  14%|██████▏                                    | 1/7 [00:01<00:09,  1.63s/it]
# Looping through values of k:  29%|████████████▎                              | 2/7 [00:04<00:12,  2.54s/it]
# Looping through values of k:  43%|██████████████████▍                        | 3/7 [00:07<00:11,  2.81s/it]
# Looping through values of k:  57%|████████████████████████▌                  | 4/7 [00:11<00:08,  2.97s/it]
# Looping through values of k:  71%|██████████████████████████████▋            | 5/7 [00:14<00:06,  3.12s/it]
# Looping through values of k:  86%|████████████████████████████████████▊      | 6/7 [00:17<00:03,  3.20s/it]
# Looping through values of k: 100%|███████████████████████████████████████████| 7/7 [00:21<00:00,  3.24s/it]
# Evaluating n_components:  20%|█████████▏                                    | 3/15 [01:45<07:04, 35.34s/it]
# Looping through values of k:   0%|                                                   | 0/7 [00:00<?, ?it/s]
# Looping through values of k:  14%|██████▏                                    | 1/7 [00:01<00:10,  1.77s/it]
# Looping through values of k:  29%|████████████▎                              | 2/7 [00:03<00:08,  1.73s/it]
# Looping through values of k:  43%|██████████████████▍                        | 3/7 [00:05<00:07,  1.77s/it]
# Looping through values of k:  57%|████████████████████████▌                  | 4/7 [00:07<00:05,  1.78s/it]
# Looping through values of k:  71%|██████████████████████████████▋            | 5/7 [00:08<00:03,  1.76s/it]
# Looping through values of k:  86%|████████████████████████████████████▊      | 6/7 [00:10<00:01,  1.76s/it]
# Looping through values of k: 100%|███████████████████████████████████████████| 7/7 [00:12<00:00,  1.75s/it]
#
# Looping through values of k:   0%|                                                   | 0/7 [00:00<?, ?it/s]
# Looping through values of k:  14%|██████▏                                    | 1/7 [00:02<00:17,  2.85s/it]
# Looping through values of k:  29%|████████████▎                              | 2/7 [00:06<00:15,  3.12s/it]
# Looping through values of k:  43%|██████████████████▍                        | 3/7 [00:07<00:09,  2.34s/it]
# Looping through values of k:  57%|████████████████████████▌                  | 4/7 [00:10<00:08,  2.72s/it]
# Looping through values of k:  71%|██████████████████████████████▋            | 5/7 [00:13<00:05,  2.84s/it]
# Looping through values of k:  86%|████████████████████████████████████▊      | 6/7 [00:16<00:02,  2.67s/it]
# Looping through values of k: 100%|███████████████████████████████████████████| 7/7 [00:17<00:00,  2.27s/it]
# Evaluating n_components:  27%|████████████▎                                 | 4/15 [02:19<06:19, 34.48s/it]
# Looping through values of k:   0%|                                                   | 0/7 [00:00<?, ?it/s]
# Looping through values of k:  14%|██████▏                                    | 1/7 [00:01<00:11,  1.88s/it]
# Looping through values of k:  29%|████████████▎                              | 2/7 [00:03<00:08,  1.79s/it]
# Looping through values of k:  43%|██████████████████▍                        | 3/7 [00:05<00:07,  1.88s/it]
# Looping through values of k:  57%|████████████████████████▌                  | 4/7 [00:07<00:05,  1.84s/it]
# Looping through values of k:  71%|██████████████████████████████▋            | 5/7 [00:09<00:03,  1.81s/it]
# Looping through values of k:  86%|████████████████████████████████████▊      | 6/7 [00:10<00:01,  1.79s/it]
# Looping through values of k: 100%|███████████████████████████████████████████| 7/7 [00:12<00:00,  1.75s/it]
#
# Looping through values of k:   0%|                                                   | 0/7 [00:00<?, ?it/s]
# Looping through values of k:  14%|██████▏                                    | 1/7 [00:01<00:11,  1.86s/it]
# Looping through values of k:  29%|████████████▎                              | 2/7 [00:03<00:09,  1.98s/it]
# Looping through values of k:  43%|██████████████████▍                        | 3/7 [00:06<00:09,  2.32s/it]
# Looping through values of k:  57%|████████████████████████▌                  | 4/7 [00:08<00:06,  2.33s/it]
# Looping through values of k:  71%|██████████████████████████████▋            | 5/7 [00:11<00:04,  2.34s/it]
# Looping through values of k:  86%|████████████████████████████████████▊      | 6/7 [00:14<00:02,  2.71s/it]
# Looping through values of k: 100%|███████████████████████████████████████████| 7/7 [00:18<00:00,  2.92s/it]
# Evaluating n_components:  33%|███████████████▎                              | 5/15 [02:53<05:42, 34.29s/it]
# Looping through values of k:   0%|                                                   | 0/7 [00:00<?, ?it/s]
# Looping through values of k:  14%|██████▏                                    | 1/7 [00:01<00:11,  1.92s/it]
# Looping through values of k:  29%|████████████▎                              | 2/7 [00:03<00:09,  1.82s/it]
# Looping through values of k:  43%|██████████████████▍                        | 3/7 [00:05<00:07,  1.80s/it]
# Looping through values of k:  57%|████████████████████████▌                  | 4/7 [00:07<00:05,  1.78s/it]
# Looping through values of k:  71%|██████████████████████████████▋            | 5/7 [00:08<00:03,  1.74s/it]
# Looping through values of k:  86%|████████████████████████████████████▊      | 6/7 [00:10<00:01,  1.72s/it]
# Looping through values of k: 100%|███████████████████████████████████████████| 7/7 [00:12<00:00,  1.71s/it]
#
# Looping through values of k:   0%|                                                   | 0/7 [00:00<?, ?it/s]
# Looping through values of k:  14%|██████▏                                    | 1/7 [00:02<00:14,  2.47s/it]
# Looping through values of k:  29%|████████████▎                              | 2/7 [00:05<00:14,  2.98s/it]
# Looping through values of k:  43%|██████████████████▍                        | 3/7 [00:08<00:12,  3.03s/it]
# Looping through values of k:  57%|████████████████████████▌                  | 4/7 [00:10<00:07,  2.37s/it]
# Looping through values of k:  71%|██████████████████████████████▋            | 5/7 [00:13<00:05,  2.76s/it]
# Looping through values of k:  86%|████████████████████████████████████▊      | 6/7 [00:17<00:02,  2.97s/it]
# Looping through values of k: 100%|███████████████████████████████████████████| 7/7 [00:20<00:00,  3.01s/it]
# Evaluating n_components:  40%|██████████████████▍                           | 6/15 [03:28<05:11, 34.58s/it]
# Looping through values of k:   0%|                                                   | 0/7 [00:00<?, ?it/s]
# Looping through values of k:  14%|██████▏                                    | 1/7 [00:01<00:10,  1.78s/it]
# Looping through values of k:  29%|████████████▎                              | 2/7 [00:03<00:08,  1.73s/it]
# Looping through values of k:  43%|██████████████████▍                        | 3/7 [00:05<00:07,  1.77s/it]
# Looping through values of k:  57%|████████████████████████▌                  | 4/7 [00:06<00:05,  1.73s/it]
# Looping through values of k:  71%|██████████████████████████████▋            | 5/7 [00:08<00:03,  1.71s/it]
# Looping through values of k:  86%|████████████████████████████████████▊      | 6/7 [00:10<00:01,  1.69s/it]
# Looping through values of k: 100%|███████████████████████████████████████████| 7/7 [00:11<00:00,  1.67s/it]
#
# Looping through values of k:   0%|                                                   | 0/7 [00:00<?, ?it/s]
# Looping through values of k:  14%|██████▏                                    | 1/7 [00:02<00:12,  2.02s/it]
# Looping through values of k:  29%|████████████▎                              | 2/7 [00:05<00:14,  2.81s/it]
# Looping through values of k:  43%|██████████████████▍                        | 3/7 [00:08<00:12,  3.10s/it]
# Looping through values of k:  57%|████████████████████████▌                  | 4/7 [00:12<00:09,  3.22s/it]
# Looping through values of k:  71%|██████████████████████████████▋            | 5/7 [00:15<00:06,  3.24s/it]
# Looping through values of k:  86%|████████████████████████████████████▊      | 6/7 [00:18<00:03,  3.29s/it]
# Looping through values of k: 100%|███████████████████████████████████████████| 7/7 [00:22<00:00,  3.48s/it]
# Evaluating n_components:  47%|█████████████████████▍                        | 7/15 [04:06<04:47, 35.94s/it]
# Looping through values of k:   0%|                                                   | 0/7 [00:00<?, ?it/s]
# Looping through values of k:  14%|██████▏                                    | 1/7 [00:01<00:11,  1.93s/it]
# Looping through values of k:  29%|████████████▎                              | 2/7 [00:03<00:09,  1.80s/it]
# Looping through values of k:  43%|██████████████████▍                        | 3/7 [00:05<00:07,  1.77s/it]
# Looping through values of k:  57%|████████████████████████▌                  | 4/7 [00:07<00:05,  1.74s/it]
# Looping through values of k:  71%|██████████████████████████████▋            | 5/7 [00:08<00:03,  1.75s/it]
# Looping through values of k:  86%|████████████████████████████████████▊      | 6/7 [00:10<00:01,  1.85s/it]
# Looping through values of k: 100%|███████████████████████████████████████████| 7/7 [00:12<00:00,  1.81s/it]
#
# Looping through values of k:   0%|                                                   | 0/7 [00:00<?, ?it/s]
# Looping through values of k:  14%|██████▏                                    | 1/7 [00:03<00:19,  3.22s/it]
# Looping through values of k:  29%|████████████▎                              | 2/7 [00:06<00:16,  3.37s/it]
# Looping through values of k:  43%|██████████████████▍                        | 3/7 [00:10<00:13,  3.39s/it]
# Looping through values of k:  57%|████████████████████████▌                  | 4/7 [00:13<00:09,  3.32s/it]
# Looping through values of k:  71%|██████████████████████████████▋            | 5/7 [00:16<00:06,  3.12s/it]
# Looping through values of k:  86%|████████████████████████████████████▊      | 6/7 [00:19<00:03,  3.21s/it]
# Looping through values of k: 100%|███████████████████████████████████████████| 7/7 [00:23<00:00,  3.39s/it]
# Evaluating n_components:  53%|████████████████████████▌                     | 8/15 [04:46<04:19, 37.06s/it]
# Looping through values of k:   0%|                                                   | 0/7 [00:00<?, ?it/s]
# Looping through values of k:  14%|██████▏                                    | 1/7 [00:01<00:11,  1.85s/it]
# Looping through values of k:  29%|████████████▎                              | 2/7 [00:03<00:08,  1.76s/it]
# Looping through values of k:  43%|██████████████████▍                        | 3/7 [00:05<00:06,  1.72s/it]
# Looping through values of k:  57%|████████████████████████▌                  | 4/7 [00:06<00:05,  1.72s/it]
# Looping through values of k:  71%|██████████████████████████████▋            | 5/7 [00:08<00:03,  1.70s/it]
# Looping through values of k:  86%|████████████████████████████████████▊      | 6/7 [00:10<00:01,  1.69s/it]
# Looping through values of k: 100%|███████████████████████████████████████████| 7/7 [00:11<00:00,  1.68s/it]
#
# Looping through values of k:   0%|                                                   | 0/7 [00:00<?, ?it/s]
# Looping through values of k:  14%|██████▏                                    | 1/7 [00:03<00:19,  3.19s/it]
# Looping through values of k:  29%|████████████▎                              | 2/7 [00:06<00:17,  3.44s/it]
# Looping through values of k:  43%|██████████████████▍                        | 3/7 [00:10<00:13,  3.48s/it]
# Looping through values of k:  57%|████████████████████████▌                  | 4/7 [00:13<00:09,  3.28s/it]
# Looping through values of k:  71%|██████████████████████████████▋            | 5/7 [00:17<00:06,  3.43s/it]
# Looping through values of k:  86%|████████████████████████████████████▊      | 6/7 [00:20<00:03,  3.52s/it]
# Looping through values of k: 100%|███████████████████████████████████████████| 7/7 [00:24<00:00,  3.57s/it]
# Evaluating n_components:  60%|███████████████████████████▌                  | 9/15 [05:26<03:48, 38.08s/it]
# Looping through values of k:   0%|                                                   | 0/7 [00:00<?, ?it/s]
# Looping through values of k:  14%|██████▏                                    | 1/7 [00:01<00:10,  1.82s/it]
# Looping through values of k:  29%|████████████▎                              | 2/7 [00:03<00:08,  1.78s/it]
# Looping through values of k:  43%|██████████████████▍                        | 3/7 [00:05<00:07,  1.78s/it]
# Looping through values of k:  57%|████████████████████████▌                  | 4/7 [00:07<00:05,  1.80s/it]
# Looping through values of k:  71%|██████████████████████████████▋            | 5/7 [00:08<00:03,  1.77s/it]
# Looping through values of k:  86%|████████████████████████████████████▊      | 6/7 [00:10<00:01,  1.77s/it]
# Looping through values of k: 100%|███████████████████████████████████████████| 7/7 [00:12<00:00,  1.74s/it]
#
# Looping through values of k:   0%|                                                   | 0/7 [00:00<?, ?it/s]
# Looping through values of k:  14%|██████▏                                    | 1/7 [00:02<00:13,  2.24s/it]
# Looping through values of k:  29%|████████████▎                              | 2/7 [00:04<00:10,  2.17s/it]
# Looping through values of k:  43%|██████████████████▍                        | 3/7 [00:07<00:10,  2.58s/it]
# Looping through values of k:  57%|████████████████████████▌                  | 4/7 [00:10<00:08,  2.85s/it]
# Looping through values of k:  71%|██████████████████████████████▋            | 5/7 [00:14<00:06,  3.15s/it]
# Looping through values of k:  86%|████████████████████████████████████▊      | 6/7 [00:18<00:03,  3.36s/it]
# Looping through values of k: 100%|███████████████████████████████████████████| 7/7 [00:21<00:00,  3.51s/it]
# Evaluating n_components:  67%|██████████████████████████████               | 10/15 [06:05<03:11, 38.22s/it]
# Looping through values of k:   0%|                                                   | 0/7 [00:00<?, ?it/s]
# Looping through values of k:  14%|██████▏                                    | 1/7 [00:01<00:10,  1.77s/it]
# Looping through values of k:  29%|████████████▎                              | 2/7 [00:03<00:08,  1.72s/it]
# Looping through values of k:  43%|██████████████████▍                        | 3/7 [00:05<00:07,  1.77s/it]
# Looping through values of k:  57%|████████████████████████▌                  | 4/7 [00:06<00:05,  1.75s/it]
# Looping through values of k:  71%|██████████████████████████████▋            | 5/7 [00:08<00:03,  1.73s/it]
# Looping through values of k:  86%|████████████████████████████████████▊      | 6/7 [00:10<00:01,  1.72s/it]
# Looping through values of k: 100%|███████████████████████████████████████████| 7/7 [00:12<00:00,  1.69s/it]
#
# Looping through values of k:   0%|                                                   | 0/7 [00:00<?, ?it/s]
# Looping through values of k:  14%|██████▏                                    | 1/7 [00:02<00:13,  2.27s/it]
# Looping through values of k:  29%|████████████▎                              | 2/7 [00:03<00:09,  1.89s/it]
# Looping through values of k:  43%|██████████████████▍                        | 3/7 [00:05<00:06,  1.72s/it]
# Looping through values of k:  57%|████████████████████████▌                  | 4/7 [00:07<00:06,  2.02s/it]
# Looping through values of k:  71%|██████████████████████████████▋            | 5/7 [00:11<00:04,  2.44s/it]
# Looping through values of k:  86%|████████████████████████████████████▊      | 6/7 [00:14<00:02,  2.67s/it]
# Looping through values of k: 100%|███████████████████████████████████████████| 7/7 [00:16<00:00,  2.62s/it]
# Evaluating n_components:  73%|█████████████████████████████████            | 11/15 [06:38<02:26, 36.65s/it]
# Looping through values of k:   0%|                                                   | 0/7 [00:00<?, ?it/s]
# Looping through values of k:  14%|██████▏                                    | 1/7 [00:01<00:10,  1.80s/it]
# Looping through values of k:  29%|████████████▎                              | 2/7 [00:03<00:08,  1.73s/it]
# Looping through values of k:  43%|██████████████████▍                        | 3/7 [00:05<00:06,  1.69s/it]
# Looping through values of k:  57%|████████████████████████▌                  | 4/7 [00:06<00:05,  1.67s/it]
# Looping through values of k:  71%|██████████████████████████████▋            | 5/7 [00:08<00:03,  1.66s/it]
# Looping through values of k:  86%|████████████████████████████████████▊      | 6/7 [00:10<00:01,  1.67s/it]
# Looping through values of k: 100%|███████████████████████████████████████████| 7/7 [00:11<00:00,  1.69s/it]
#
# Looping through values of k:   0%|                                                   | 0/7 [00:00<?, ?it/s]
# Looping through values of k:  14%|██████▏                                    | 1/7 [00:02<00:17,  3.00s/it]
# Looping through values of k:  29%|████████████▎                              | 2/7 [00:06<00:16,  3.30s/it]
# Looping through values of k:  43%|██████████████████▍                        | 3/7 [00:10<00:13,  3.40s/it]
# Looping through values of k:  57%|████████████████████████▌                  | 4/7 [00:13<00:10,  3.50s/it]
# Looping through values of k:  71%|██████████████████████████████▋            | 5/7 [00:16<00:06,  3.41s/it]
# Looping through values of k:  86%|████████████████████████████████████▊      | 6/7 [00:20<00:03,  3.53s/it]
# Looping through values of k: 100%|███████████████████████████████████████████| 7/7 [00:24<00:00,  3.58s/it]
# Evaluating n_components:  80%|████████████████████████████████████         | 12/15 [07:18<01:53, 37.78s/it]
# Looping through values of k:   0%|                                                   | 0/7 [00:00<?, ?it/s]
# Looping through values of k:  14%|██████▏                                    | 1/7 [00:01<00:10,  1.80s/it]
# Looping through values of k:  29%|████████████▎                              | 2/7 [00:03<00:08,  1.76s/it]
# Looping through values of k:  43%|██████████████████▍                        | 3/7 [00:05<00:06,  1.73s/it]
# Looping through values of k:  57%|████████████████████████▌                  | 4/7 [00:06<00:05,  1.72s/it]
# Looping through values of k:  71%|██████████████████████████████▋            | 5/7 [00:08<00:03,  1.70s/it]
# Looping through values of k:  86%|████████████████████████████████████▊      | 6/7 [00:10<00:01,  1.71s/it]
# Looping through values of k: 100%|███████████████████████████████████████████| 7/7 [00:12<00:00,  1.72s/it]
#
# Looping through values of k:   0%|                                                   | 0/7 [00:00<?, ?it/s]
# Looping through values of k:  14%|██████▏                                    | 1/7 [00:03<00:18,  3.16s/it]
# Looping through values of k:  29%|████████████▎                              | 2/7 [00:06<00:17,  3.43s/it]
# Looping through values of k:  43%|██████████████████▍                        | 3/7 [00:10<00:14,  3.53s/it]
# Looping through values of k:  57%|████████████████████████▌                  | 4/7 [00:14<00:10,  3.61s/it]
# Looping through values of k:  71%|██████████████████████████████▋            | 5/7 [00:17<00:07,  3.50s/it]
# Looping through values of k:  86%|████████████████████████████████████▊      | 6/7 [00:21<00:03,  3.63s/it]
# Looping through values of k: 100%|███████████████████████████████████████████| 7/7 [00:25<00:00,  3.69s/it]
# Evaluating n_components:  87%|███████████████████████████████████████      | 13/15 [08:00<01:18, 39.00s/it]
# Looping through values of k:   0%|                                                   | 0/7 [00:00<?, ?it/s]
# Looping through values of k:  14%|██████▏                                    | 1/7 [00:01<00:11,  1.85s/it]
# Looping through values of k:  29%|████████████▎                              | 2/7 [00:03<00:08,  1.78s/it]
# Looping through values of k:  43%|██████████████████▍                        | 3/7 [00:05<00:07,  1.76s/it]
# Looping through values of k:  57%|████████████████████████▌                  | 4/7 [00:07<00:05,  1.74s/it]
# Looping through values of k:  71%|██████████████████████████████▋            | 5/7 [00:08<00:03,  1.75s/it]
# Looping through values of k:  86%|████████████████████████████████████▊      | 6/7 [00:10<00:01,  1.73s/it]
# Looping through values of k: 100%|███████████████████████████████████████████| 7/7 [00:12<00:00,  1.71s/it]
#
# Looping through values of k:   0%|                                                   | 0/7 [00:00<?, ?it/s]
# Looping through values of k:  14%|██████▏                                    | 1/7 [00:02<00:17,  2.94s/it]
# Looping through values of k:  29%|████████████▎                              | 2/7 [00:06<00:16,  3.34s/it]
# Looping through values of k:  43%|██████████████████▍                        | 3/7 [00:10<00:13,  3.48s/it]
# Looping through values of k:  57%|████████████████████████▌                  | 4/7 [00:13<00:10,  3.53s/it]
# Looping through values of k:  71%|██████████████████████████████▋            | 5/7 [00:17<00:07,  3.52s/it]
# Looping through values of k:  86%|████████████████████████████████████▊      | 6/7 [00:20<00:03,  3.55s/it]
# Looping through values of k: 100%|███████████████████████████████████████████| 7/7 [00:24<00:00,  3.62s/it]
# Evaluating n_components:  93%|██████████████████████████████████████████   | 14/15 [08:42<00:39, 39.83s/it]
# Looping through values of k:   0%|                                                   | 0/7 [00:00<?, ?it/s]
# Looping through values of k:  14%|██████▏                                    | 1/7 [00:01<00:11,  1.89s/it]
# Looping through values of k:  29%|████████████▎                              | 2/7 [00:03<00:09,  1.84s/it]
# Looping through values of k:  43%|██████████████████▍                        | 3/7 [00:05<00:07,  1.79s/it]
# Looping through values of k:  57%|████████████████████████▌                  | 4/7 [00:07<00:05,  1.77s/it]
# Looping through values of k:  71%|██████████████████████████████▋            | 5/7 [00:08<00:03,  1.78s/it]
# Looping through values of k:  86%|████████████████████████████████████▊      | 6/7 [00:10<00:01,  1.77s/it]
# Looping through values of k: 100%|███████████████████████████████████████████| 7/7 [00:12<00:00,  1.76s/it]
#
# Looping through values of k:   0%|                                                   | 0/7 [00:00<?, ?it/s]
# Looping through values of k:  14%|██████▏                                    | 1/7 [00:01<00:08,  1.47s/it]
# Looping through values of k:  29%|████████████▎                              | 2/7 [00:04<00:12,  2.46s/it]
# Looping through values of k:  43%|██████████████████▍                        | 3/7 [00:08<00:12,  3.04s/it]
# Looping through values of k:  57%|████████████████████████▌                  | 4/7 [00:12<00:09,  3.30s/it]
# Looping through values of k:  71%|██████████████████████████████▋            | 5/7 [00:15<00:06,  3.44s/it]
# Looping through values of k:  86%|████████████████████████████████████▊      | 6/7 [00:19<00:03,  3.59s/it]
# Looping through values of k: 100%|███████████████████████████████████████████| 7/7 [00:23<00:00,  3.68s/it]
# Evaluating n_components: 100%|█████████████████████████████████████████████| 15/15 [09:22<00:00, 37.51s/it]

# %%
merged_dict_hyper = {key: {'Variance Explained': variance_explained[key], 
                           'K Means Silhouette Scores': kmeans_silhouette_scores[key], 
                           'Hierarchical Silhouette Scores': hierarchical_silhouette_scores[key]} for key in variance_explained}
merged_df_hyper = pd.DataFrame.from_dict(merged_dict_hyper, orient='index')

merged_df_hyper.reset_index(inplace=True)
merged_df_hyper.columns = ['n_components', 'Variance Explained', 'K-Means Silhouette Scores', 'Hierarchical Silhouette Scores']

merged_df_hyper
# Out:
#     n_components Variance Explained  \
# 0              2             24.80%
# 1              3             32.08%
# 2              4             38.85%
# 3              5             44.58%
# 4              6             50.21%
# 5              7             55.66%
# 6              8             61.04%
# 7              9             66.28%
# 8             10             71.36%
# 9             11             76.06%
# 10            12             80.63%
# 11            13             84.91%
# 12            14             88.88%
# 13            15             92.47%
# 14            16             95.85%
#
#                             K-Means Silhouette Scores  \
# 0   {2: 0.45731362320582775, 3: 0.4616456820139469...
# 1   {2: 0.3559861558068792, 3: 0.3388348464003746,...
# 2   {2: 0.30016395421469616, 3: 0.2813175626600281...
# 3   {2: 0.2661039374137766, 3: 0.2435047064677586,...
# 4   {2: 0.2451334937861231, 3: 0.2213845413574486,...
# 5   {2: 0.22204922574571936, 3: 0.1989596509680531...
# 6   {2: 0.20500945039254195, 3: 0.1831766231769521...
# 7   {2: 0.1930789153523736, 3: 0.17033382530631588...
# 8   {2: 0.1828386886468414, 3: 0.16100431588253317...
# 9   {2: 0.17137085940996005, 3: 0.1826463044368094...
# 10  {2: 0.16130249110027223, 3: 0.1414770400515471...
# 11  {2: 0.15308157105274278, 3: 0.1312855901242516...
# 12  {2: 0.14567829941076182, 3: 0.1570850885866317...
# 13  {2: 0.1395802838585977, 3: 0.15096950805093295...
# 14  {2: 0.13485594218473118, 3: 0.1456840034811072...
#
#                        Hierarchical Silhouette Scores
# 0   {2: 0.4391403709343355, 3: 0.4262838184710653,...
# 1   {2: 0.34218277823346555, 3: 0.3042418667043540...
# 2   {2: 0.3079967141008697, 3: 0.22408598264808746...
# 3   {2: 0.28024473795637006, 3: 0.2682812967786623...
# 4   {2: 0.4150110171898443, 3: 0.40669061039092186...
# 5   {2: 0.41009227766936296, 3: 0.4025321103247137...
# 6   {2: 0.41335378022947655, 3: 0.1992474059494418...
# 7   {2: 0.4322963295311603, 3: 0.4230876252323627,...
# 8   {2: 0.4162707101194707, 3: 0.19255968831900583...
# 9   {2: 0.40355138988992084, 3: 0.2100764435711117...
# 10  {2: 0.3921257772531665, 3: 0.3778385320827574,...
# 11  {2: 0.3813592452631955, 3: 0.19250571978254802...
# 12  {2: 0.3715276816229854, 3: 0.35702065084371687...
# 13  {2: 0.36238742841604576, 3: 0.3478637964787626...
# 14  {2: 0.35514740899774055, 3: 0.3407061993701064...

# %%
# Use lambda function to extract the maximum value from each dictionary directly
merged_df_hyper['Best K-Means Silhouette Score'] = merged_df_hyper['K-Means Silhouette Scores'].apply(lambda x: max(x.values()))
merged_df_hyper['Best K-Means k'] = merged_df_hyper['K-Means Silhouette Scores'].apply(lambda x: max(x, key=x.get))
merged_df_hyper['Best Average K-Means Silhouette Score'] = merged_df_hyper['K-Means Silhouette Scores'].apply(lambda x: mean(x.values()))

merged_df_hyper['Best Hierarchical Silhouette Score'] = merged_df_hyper['Hierarchical Silhouette Scores'].apply(lambda x: max(x.values()))
merged_df_hyper['Best Hierarchical k'] = merged_df_hyper['Hierarchical Silhouette Scores'].apply(lambda x: max(x, key=x.get))
merged_df_hyper['Best Average Hierarchical Silhouette Score'] = merged_df_hyper['Hierarchical Silhouette Scores'].apply(lambda x: mean(x.values()))

merged_df_hyper.to_csv('hyperparameter_file_mca_kmeans.csv', index=False)

# %%
# Create a scatter plot
plt.figure(figsize=(10, 6))
sns.scatterplot(data=merged_df_hyper, x='Variance Explained', y='Best Average K-Means Silhouette Score', hue='n_components', s=100)

# Adding titles and labels
plt.title('Variance Explained and Silhouette Scores for K-Means')
plt.xlabel('Variance Explained')
plt.ylabel('Best K-Means Silhouette Score')
plt.grid(True)

# Rotate labels
plt.xticks(rotation=90)  
plt.yticks(rotation=0)   

# Show legend with title
plt.legend(title='n_components')
plt.show()

# %%
# Create a scatter plot
plt.figure(figsize=(10, 6))
sns.scatterplot(data=merged_df_hyper, x='Variance Explained', y='Best Average Hierarchical Silhouette Score', hue='n_components', s=100)

# Adding titles and labels
plt.title('Variance Explained and Silhouette Scores for Hierarchical')
plt.xlabel('Variance Explained')
plt.ylabel('Best Hierarchical Silhouette Score')
plt.grid(True)

# Rotate labels
plt.xticks(rotation=90)  
plt.yticks(rotation=0) 

# Show legend with title
plt.legend(title='n_components')
plt.show()
